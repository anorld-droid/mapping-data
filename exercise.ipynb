# %% [markdown]
# # Practice your skills loading data from a CSV file
# In this exercise, you will load a CSV file and you'll perform some operations on it to extract data. If you know how to do this with the Pandas library, you can use that. If not, you can use the csv library with the ready-to-use example this notebook provides.

# %%
from csv import DictReader

# Open the CSV file and read it into a list of dictionaries and ignore unicode errors

with open('sample_data/wine-ratings-small.csv', encoding='utf-8', errors='ignore') as f:
    reader = DictReader(f)
    wines = list(reader)


# The wines variable is now a list of dictionaries, one for each row in the CSV file. This is the sample output of a single entry:
# {'': '1',
#  'name': 'Laurenz V Charming Gruner Veltliner 2014',
#  'grape': '',
#  'region': 'Kamptal, Austria',
#  'variety': 'White Wine',
#  'rating': '90.0',
#  'notes': ''}

# %% [markdown]
# Looping over the list of dictionaries can be tricky with plain Python. Specialized libraries like Pandas make this much easier but the downside is that you need to learn a new library. The following code is a bit more verbose but it's a good exercise to learn how to work with dictionaries in Python.

# %%
# This example creates a new list that only has wines from Napa Valley. The new list is called napa_wines:
napa_wines = []
for wine in wines:
    if 'Napa' in wine['region']:
        napa_wines.append(wine)

napa_wines

# %% [markdown]
# **NOTE**: If you are trying to use ratings, remember that you will need to convert the ratings to integers for numerical comparisons.

# %% [markdown]
# ## Using Pandas
# Alternatively, you can use the Pandas library to load the CSV file and then extract the data. You'll need to install the Pandas library first. You can do this with the following command:
#
# ```bash
# pip install pandas
# ```
#
# Then, you can use the following code to load the CSV file and extract the data:
#
# ```python
# import pandas as pd
#
# df = pd.read_csv('sample_data/wine-ratings-small.csv')
# df.head()
# ```

# %%
import pandas as pd
import json

df = pd.read_csv("sample_data/wine-ratings-small.csv", index_col=0) # read the csv file and set the index column to 0
df.head() # show the first 5 rows of the dataframe
# Out:
#                                        name  grape            region  \
# 0  Laurenz V Charming Gruner Veltliner 2013    NaN  Kamptal, Austria
# 1  Laurenz V Charming Gruner Veltliner 2014    NaN  Kamptal, Austria
# 2   Laurenz V Singing Gruner Veltliner 2007    NaN           Austria
# 3   Laurenz V Singing Gruner Veltliner 2010    NaN           Austria
# 4   Laurenz V Singing Gruner Veltliner 2011    NaN           Austria
#
#       variety  rating                                              notes
# 0  White Wine    90.0  Aromas of ripe apples and a typical Veltliner ...
# 1  White Wine    90.0  Aromas of ripe apples and a typical Veltliner ...
# 2  White Wine    90.0  A very attractive fruit bouquet yields apple, ...
# 3  White Wine    88.0  A very attractive fruit bouquet yields apple, ...
# 4  White Wine    88.0  A very attractive fruit bouquet yields apple, ...

# %% [markdown]
# ## Manipulate data with Pandas or as a dictionary
# At this point, you can use Pandas if you know how to use it. Otherwise, you can use the data as a dictionary. You can use the following code to extract the data:
#
# ```python
# data = df.to_dict()
# ```

# %%
dict_data = df.to_dict()
# You'll get several keys, one for each column in the dataframe. You can access the values of a column by using the column name as a key. You'll also
# get the index of each row as a key. You can access the values of a row by using the index as a key.

dict_data['name'] # get the values of the 'name' column
# sample output:
# {0: 'Laurenz V Charming Gruner Veltliner 2013',
# 1: 'Laurenz V Charming Gruner Veltliner 2014', ...}
# Out:
# {0: 'Laurenz V Charming Gruner Veltliner 2013',
#  1: 'Laurenz V Charming Gruner Veltliner 2014',
#  2: 'Laurenz V Singing Gruner Veltliner 2007',
#  3: 'Laurenz V Singing Gruner Veltliner 2010',
#  4: 'Laurenz V Singing Gruner Veltliner 2011',
#  5: 'Laurenz V Singing Gruner Veltliner 2013',
#  6: 'Lava Cap American River Red',
#  7: 'Lava Cap Barbera 2010',
#  8: 'Lava Cap Battonage Chardonnay 2012',
#  9: 'Lava Cap Cabernet Sauvignon 2013',
#  10: 'Lava Cap Cabernet Sauvignon 2016',
#  11: 'Lava Cap Petite Sirah 2013',
#  12: 'Lava Cap Petite Sirah 2014',
#  13: 'Lava Cap Petite Sirah 2016',
#  14: 'Lava Cap Reserve Chardonnay 2015',
#  15: 'Lava Cap Reserve Chardonnay 2018',
#  16: 'Lava Cap Reserve Chardonnay 2016',
#  17: 'Lava Cap Reserve Merlot 2015',
#  18: 'Lava Cap Sauvignon Blanc 2015',
#  19: 'Lava Cap Sauvignon Blanc 2017',
#  20: 'Lava Cap Syrah 2009',
#  21: 'Lava Cap Syrah 2014',
#  22: 'Lava Cap Syrah 2013',
#  23: 'Lava Vine Winery Knights Valley Reserve Cabernet Sauvignon 2013',
#  24: 'Lava Vine Winery Napa Valley Cabernet Sauvignon 2014',
#  25: 'Lava Vine Winery Napa Valley Reserve Cabernet Sauvignon 2012',
#  26: 'Lava Vine Winery Napa Valley Reserve Cabernet Sauvignon 2013',
#  27: 'Lavau Chateauneuf-du-Pape 2016',
#  28: 'Lavau Chateauneuf-du-Pape 2014',
#  29: 'Lavau Chateauneuf-du-Pape 2015',
#  30: 'Lavau Gigondas 2013',
#  31: 'Lavau Gigondas 2013',
#  32: 'Lavau Gigondas 2014',
#  33: 'Lavau Gigondas 2015',
#  34: 'Lavau Gigondas 2016',
#  35: 'Lavau Rasteau 2015',
#  36: 'Lavau Rasteau 2016',
#  37: "L'Aventure Cabernet Sauvignon 2006",
#  38: "L'Aventure Chloe 2014",
#  39: "L'Aventure Cote A Cote 2006",
#  40: "L'Aventure Cote A Cote 2007",
#  41: "L'Aventure Cote A Cote 2010",
#  42: "L'Aventure Cote A Cote 2011",
#  43: "L'Aventure Cote A Cote 2014",
#  44: "L'Aventure Cote A Cote (slightly stained labels) 2012",
#  45: "L'Aventure Estate Cuvee (1.5 Liter Magnum) 2008",
#  46: "L'Aventure Estate Cuvee 2004",
#  47: "L'Aventure Estate Cuvee 2005",
#  48: "L'Aventure Estate Cuvee 2006",
#  49: "L'Aventure Estate Cuvee 2007",
#  50: "L'Aventure Estate Cuvee 2008",
#  51: "L'Aventure Estate Cuvee 2010",
#  52: "L'Aventure Estate Cuvee 2011",
#  53: "L'Aventure Estate Cuvee 2013",
#  54: "L'Aventure Estate Cuvee 2012",
#  55: "L'Aventure Estate Cuvee 2014",
#  56: "L'Aventure Estate Cuvee 2016",
#  57: "L'Aventure Optimus (1.5 Liter Magnum) 2012",
#  58: "L'Aventure Optimus 2005",
#  59: "L'Aventure Optimus 2007",
#  60: "L'Aventure Optimus 2008",
#  61: "L'Aventure Optimus 2011",
#  62: "L'Aventure Optimus 2015",
#  63: "L'Aventure Optimus 2016",
#  64: "L'Aventure Optimus 2017",
#  65: "L'Aventure Optimus 2012",
#  66: 'Lavinea Elton Chardonnay 2016',
#  67: 'Lavinea Elton Pinot Noir 2016',
#  68: 'Lavinea Lazy River Pinot Noir 2016',
#  69: 'Lavinea Nysa Pinot Noir 2016',
#  70: 'Lavinea Tualatin Pinot Noir 2016',
#  71: 'Lavinea Tualatin Pinot Noir 2017',
#  72: 'Lavradores de Feitoria Tres Bagos 2003',
#  73: 'Lavradores de Feitoria Tres Bagos 2004',
#  74: 'Law Estate Wines Audacious 2016',
#  75: 'Law Estate Wines Sagacious 2016',
#  76: "Lawson's Dry Hills Gewurztraminer 2009",
#  77: "Lawson's Dry Hills Gewurztraminer 2014",
#  78: "Lawson's Dry Hills Pinot Noir 2005",
#  79: "Lawson's Dry Hills Sauvignon Blanc 2014",
#  80: 'Layer Cake Cabernet Sauvignon 2010',
#  81: 'Layer Cake Chardonnay 2011',
#  82: 'Layer Cake Garnacha 2011',
#  83: 'Layer Cake Malbec 2008',
#  84: 'Layer Cake Primitivo aka Zinfandel 2008',
#  85: 'Layer Cake Shiraz 2008',
#  86: 'Layer Cake Shiraz 2009',
#  87: 'Layer Cake Shiraz 2014',
#  88: 'Layer Cake Shiraz 2013',
#  89: 'Layer Cake Shiraz 2010',
#  90: 'Layer Cake Virgin Chardonnay 2009',
#  91: 'Le Berne Vino Nobile di Montepulciano 2011',
#  92: 'Le Bonheur Cabernet Sauvignon 1997',
#  93: 'Le Bonheur Chardonnay 1999',
#  94: 'Le Brun de Neuville Authentique Brut Assemblage',
#  95: 'Le Cadeau Vineyard Diversite Pinot Noir 2014',
#  96: 'Le Cadeau Vineyard Diversite Pinot Noir 2015',
#  97: 'Le Cadeau Vineyard Rocheux Pinot Noir 2015',
#  98: 'Le Cadeau Vineyard Rocheux Pinot Noir 2016',
#  99: 'Le Cadeau Vineyard Rocheux Reserve Pinot Noir 2014',
#  100: 'Le Carre 2007',
#  101: 'Le Carre 2008',
#  102: 'Le Carre 2009',
#  103: 'Le Carre 2010',
#  104: 'Le Carre 2011',
#  105: 'Le Carre 2012',
#  106: 'Le Casematte Faro 2014',
#  107: 'Le Casematte Faro 2013',
#  108: 'Le Casematte Faro 2016',
#  109: "Le Casematte Nero d'Avola 2015",
#  110: 'Le Casematte Peloro Rosso 2014',
#  111: 'Le Casematte Peloro Rosso 2015',
#  112: 'Le Casematte Peloro Bianco 2017',
#  113: 'Le Casematte Peloro Rosso 2017',
#  114: 'Le Charmel Rhone Blend 2011',
#  115: 'Le Chiuse Brunello di Montalcino 2008',
#  116: 'Le Chiuse Brunello di Montalcino 2010',
#  117: 'Le Chiuse Brunello di Montalcino 2011',
#  118: 'Le Chiuse Brunello di Montalcino 2012',
#  119: 'Le Chiuse Brunello di Montalcino 2013',
#  120: 'Le Chiuse Brunello di Montalcino 2015',
#  121: 'Le Chiuse Brunello di Montalcino (375ML half-bottle) 2011',
#  122: 'Le Chiuse Brunello di Montalcino (375ML half-bottle) 2013',
#  123: 'Le Chiuse Brunello di Montalcino (375ML half-bottle) 2012',
#  124: 'Le Chiuse Brunello di Montalcino Riserva 2006',
#  125: 'Le Chiuse Brunello di Montalcino Riserva 2009',
#  126: 'Le Chiuse Rosso di Montalcino 2015',
#  127: 'Le Chiuse Rosso di Montalcino 2017',
#  128: 'Le Cirque Grenache Gris 2014',
#  129: 'Le Cirque Grenache Gris 2015',
#  130: 'Le Cirque Rouge 2014',
#  131: "Le Clos d'un Jour Un Jour sur Terre Cahors 2005",
#  132: 'Le Colture Brut Rose',
#  133: 'Le Colture Fagher Prosecco Superiore Brut',
#  134: 'Le Colture Prosecco Superiore di Cartizze',
#  135: 'Le Corti Chianti Classico 2011',
#  136: 'Le Corti Chianti Classico 2012',
#  137: 'Le Corti Chianti Classico 2013',
#  138: 'Le Corti Don Tommaso Chianti Classico 2007',
#  139: 'Le Corti Chianti Classico 2016',
#  140: 'Le Corti Don Tommaso Chianti Classico 2008',
#  141: 'Le Corti Don Tommaso Chianti Classico 2013',
#  142: 'Le Corti Don Tommaso Chianti Classico 2014',
#  143: 'Le Corti Don Tommaso Chianti Classico 2009',
#  144: 'Le Corti Tenuta Birillo Rosso 2010',
#  145: "Le Domaine D'Henri Chablis Fourchaume Premier Cru 2014",
#  146: "Le Domaine D'Henri Chablis Fourchaume Premier Cru 2015",
#  147: "Le Domaine D'Henri Chablis Fourchaume Premier Cru Vieilles Vignes 2014",
#  148: 'Le Dome 2006',
#  149: 'Le Dome 2008',
#  150: 'Le Dome 2009',
#  151: 'Le Dome 2011',
#  152: 'Le Dome 2012',
#  153: 'Le Due Terre Colli Orientali del Friuli Sacrisassi 2005',
#  154: 'Le Due Terre Colli Orientali del Friuli Sacrisassi 2007',
#  155: 'Le Dome 2016',
#  156: 'Le Dome 2010',
#  157: 'Le Dome 2014',
#  158: 'Le Fonti Chianti Classico 2009',
#  159: 'Le Grand Courtage Blanc de Blancs Brut Bedazzled Bottle',
#  160: 'Le Grand Courtage Rose Brut Bedazzled Bottle',
#  161: 'Le Jas des Papes Chateauneuf-du-Pape 2010',
#  162: 'Le Macchiole (1.5 Liter Magnum) 2013',
#  163: 'Le Macchiole 1999',
#  164: 'Le Macchiole 2006',
#  165: 'Le Macchiole 2005',
#  166: 'Le Macchiole 2008',
#  167: 'Le Macchiole 2006',
#  168: 'Le Macchiole 2009',
#  169: 'Le Macchiole 2010',
#  170: 'Le Macchiole 2013',
#  171: 'Le Macchiole Messorio (1.5 Liter Magnum) 2010',
#  172: 'Le Macchiole 2012',
#  173: 'Le Macchiole Messorio 2000',
#  174: 'Le Macchiole Messorio 2002',
#  175: 'Le Macchiole Messorio 2003',
#  176: 'Le Macchiole Messorio 2005',
#  177: 'Le Macchiole Messorio 2007',
#  178: 'Le Macchiole Messorio 2009',
#  179: 'Le Macchiole Messorio 2010',
#  180: 'Le Macchiole Messorio 2012',
#  181: 'Le Macchiole Messorio 2011',
#  182: 'Le Macchiole Messorio 2013',
#  183: 'Le Macchiole Messorio 2014',
#  184: 'Le Macchiole Paleo (1.5 Liter Magnum) 2007',
#  185: 'Le Macchiole Paleo (1.5 Liter Magnum) 2009',
#  186: 'Le Macchiole Paleo (1.5 Liter Magnum) 2011',
#  187: 'Le Macchiole Paleo 1998',
#  188: 'Le Macchiole Paleo 2003',
#  189: 'Le Macchiole Paleo 2001',
#  190: 'Le Macchiole Paleo 2004',
#  191: 'Le Macchiole Paleo 2005',
#  192: 'Le Macchiole Paleo 2007',
#  193: 'Le Macchiole Paleo 2008',
#  194: 'Le Macchiole Paleo 2009',
#  195: 'Le Macchiole Paleo 2010',
#  196: 'Le Macchiole Paleo 2011',
#  197: 'Le Macchiole Paleo 2012',
#  198: 'Le Macchiole Paleo 2013',
#  199: 'Le Macchiole Paleo 2014',
#  200: 'Le Macchiole Paleo (3 Liter Bottle) 2011',
#  201: 'Le Macchiole Paleo Bianco 2007',
#  202: 'Le Macchiole Paleo Bianco 2013',
#  203: 'Le Macchiole Paleo Bianco 2015',
#  204: 'Le Macchiole Paleo Bianco 2016',
#  205: 'Le Macchiole Paleo Bianco 2017',
#  206: 'Le Macchiole Scrio 2004',
#  207: 'Le Macchiole Scrio 2001',
#  208: 'Le Macchiole Scrio 2005',
#  209: 'Le Macchiole Scrio 2006',
#  210: 'Le Macchiole Scrio 2010',
#  211: 'Le Macchiole Scrio 2012',
#  212: 'Le Macchiole Scrio 2011',
#  213: 'Le Macchiole Scrio 2013',
#  214: 'Le Mistral 2008',
#  215: 'Le Paradou Grenache 2012',
#  216: 'Le Macchiole Scrio 2015',
#  217: 'Le Potazzine Gorelli Brunello di Montalcino 1997',
#  218: 'Le Potazzine Gorelli Brunello di Montalcino 2008',
#  219: 'Le Potazzine Gorelli Brunello di Montalcino 2009',
#  220: 'Le Potazzine Gorelli Brunello di Montalcino 2011',
#  221: 'Le Potazzine Gorelli Brunello di Montalcino 2010',
#  222: 'Le Potazzine Gorelli Brunello di Montalcino 2012',
#  223: 'Le Potazzine Rosso di Montalcino 2012',
#  224: 'Le Potazzine Gorelli Brunello di Montalcino 2013',
#  225: 'Le Potazzine Rosso di Montalcino 2014',
#  226: 'Le Potazzine Rosso di Montalcino 2015',
#  227: 'Le Potazzine Rosso di Montalcino 2017',
#  228: "Le P'tit Paysan Jack's Hill Chardonnay 2011",
#  229: "Le P'tit Paysan Jack's Hill Chardonnay 2013",
#  230: "Le P'tit Paysan Jack's Hill Chardonnay 2015",
#  231: "Le P'tit Paysan La Marea Albarino 2014",
#  232: "Le P'tit Paysan La Marea Albarino 2015",
#  233: "Le P'tit Paysan La Marea Grenache 2013",
#  234: "Le P'tit Paysan Le P'tit Pape 2011",
#  235: "Le P'tit Paysan Le P'tit Pape 2013",
#  236: "Le P'tit Paysan Le P'tit Pape 2012",
#  237: "Le P'tit Paysan Le P'tit Pape 2014",
#  238: "Le P'tit Paysan Le P'tit Pape 2015",
#  239: "Le P'tit Paysan Le P'tit Pape 2016",
#  240: "Le P'tit Paysan Le P'tit Pape 2017",
#  241: "Le P'tit Paysan Petite Sirah 2011",
#  242: "Le P'tit Paysan Petite Sirah 2013",
#  243: "Le P'tit Paysan Rose 2018",
#  244: 'Le Ragnaie Brunello di Montalcino 2010',
#  245: 'Le Ragose Amarone Della Valpolicella 2004',
#  246: 'Le Ragose Amarone Della Valpolicella 2005',
#  247: 'Le Roi des Pierres Sancerre 2014',
#  248: 'Le Roi des Pierres Sancerre 2015',
#  249: 'Le Roi des Pierres Sancerre 2016',
#  250: 'Le Roi des Pierres Sancerre Rose 2016',
#  251: 'Le Salette Amarone Classico 2011',
#  252: 'Le Salette Amarone Classico 2012',
#  253: 'Le Salette Amarone Classico 2013',
#  254: 'Le Salette Amarone della Valpolicella Pergole Vece Recioto (500ML) 2011',
#  255: 'Le Salette La Marega Amarone 2011',
#  256: 'Le Salette La Marega Amarone 2012',
#  257: 'Le Salette La Marega Amarone 2013',
#  258: 'Le Salette Pergole Vece Amarone 2008',
#  259: 'Le Salette Pergole Vece Amarone 2011',
#  260: 'Le Salette Pergole Vece Amarone 2012',
#  261: 'Le Salette Pergole Vece Amarone 2015',
#  262: 'Le Salette Valpolicella Classico 2012',
#  263: 'Le Terrazze Rosso Conero 2009',
#  264: 'Le Vieux Donjon Chateauneuf-du-Pape (1.5 Liter Magnum) 2003',
#  265: 'Le Vieux Donjon Chateauneuf-du-Pape (1.5 Liter Magnum) 2005',
#  266: 'Le Vieux Donjon Chateauneuf-du-Pape (1.5 Liter Magnum) 2012',
#  267: 'Le Vieux Donjon Chateauneuf-du-Pape (1.5 Liter Magnum) 2015',
#  268: 'Le Vieux Donjon Chateauneuf-du-Pape 2001',
#  269: 'Le Vieux Donjon Chateauneuf-du-Pape 2003',
#  270: 'Le Vieux Donjon Chateauneuf-du-Pape 2006',
#  271: 'Le Vieux Donjon Chateauneuf-du-Pape 2007',
#  272: 'Le Vieux Donjon Chateauneuf-du-Pape 2012',
#  273: 'Le Vieux Donjon Chateauneuf-du-Pape 2013',
#  274: 'Le Vieux Donjon Chateauneuf-du-Pape 2016',
#  275: 'Le Vieux Donjon Chateauneuf-du-Pape (375ML half-bottle) 2006',
#  276: 'Le Vieux Donjon Chateauneuf-du-Pape (375ML half-bottle) 2012',
#  277: 'Le Vieux Donjon Chateauneuf-du-Pape Blanc 2006',
#  278: 'Le Vigne di Eli Etna Bianco 2012',
#  279: 'Le Vigne di Eli Etna Rosso 2012',
#  280: 'Le Vigne di Eli Moganazzi-Volta Sciara Etna Rosso 2014',
#  281: 'Le Vigne di Eli Moganazzi-Volta Sciara Etna Rosso 2016',
#  282: 'Le Vigne Winery Paso Robles Cabernet Sauvignon 2016',
#  283: 'Lea Wines Sta. Rita Hills Pinot Noir 2013',
#  284: 'Lea Wines Sta. Rita Hills Pinot Noir 2014',
#  285: "Leacock's 10 Year Bual Madiera",
#  286: "Leacock's Bual 1966",
#  287: "Leacock's Rainwater Madeira",
#  288: 'Leaping Lizard Cabernet Sauvignon 2007',
#  289: 'Leasingham Bin 61 Shiraz 1997',
#  290: 'Leasingham Bin 61 Shiraz 1999',
#  291: 'Leasingham Bin 61 Shiraz 2001',
#  292: 'Leasingham Bin 61 Shiraz 2002',
#  293: 'Leasingham Bin 61 Shiraz 2000',
#  294: 'Leasingham Bin 61 Shiraz 1998',
#  295: 'Leasingham Bin 7 Riesling 2001',
#  296: 'Leasingham Bin 7 Riesling 2003',
#  297: 'Leasingham Bin 7 Riesling 2004',
#  298: 'Leasingham Bin 7 Riesling 2005',
#  299: 'Leasingham Clare Classic Cabernet Sauvignon 1997',
#  300: 'Leasingham Clare Classic Shiraz 1997',
#  301: 'Leasingham Clare Classic Shiraz 1998',
#  302: 'Leasingham Clare Classic Shiraz 2001',
#  303: 'Leasingham Clare Valley Bin 56 Cabernet Sauvignon 1999',
#  304: 'Leasingham Magnus Riesling 2003',
#  305: 'Leasingham Magnus Riesling 2006',
#  306: 'Leasingham Magnus Riesling 2007',
#  307: 'Leasingham Magnus Riesling 2004',
#  308: 'Lecheneaut Gevrey-Chambertin 2015',
#  309: 'Lecheneaut Gevrey-Chambertin 2014',
#  310: 'Lecheneaut Morey-Saint-Denis 2012',
#  311: 'Lecheneaut Morey-Saint-Denis 2016',
#  312: 'Lecheneaut Morey-St-Denis 2014',
#  313: 'Lecheneaut Morey-St-Denis 2015',
#  314: 'Lecheneaut Nuits-St. Georges 2014',
#  315: 'Lecheneaut Nuits-St. Georges 2015',
#  316: 'Lecheneaut Nuits-St. Georges Damodes Premier Cru 2011',
#  317: 'Lecheneaut Nuits-St. Georges Damodes Premier Cru 2014',
#  318: 'Lecheneaut Nuits-St. Georges Damodes Premier Cru 2015',
#  319: 'Lecheneaut Nuits-St. Georges Damodes Premier Cru 2016',
#  320: 'Lecheneaut Nuits-St-Georges Les Pruliers Premier Cru 2015',
#  321: "L'Ecole 41 Barrel Fermented Semillon 2002",
#  322: "L'Ecole 41 Barrel Fermented Semillon 2004",
#  323: "L'Ecole 41 Chardonnay 2004",
#  324: "L'Ecole 41 Chardonnay 2006",
#  325: "L'Ecole 41 Chardonnay 2005",
#  326: "L'Ecole 41 Chardonnay 2008",
#  327: "L'Ecole 41 Chardonnay 2009",
#  328: "L'Ecole 41 Chardonnay 2007",
#  329: "L'Ecole 41 Chardonnay 2012",
#  330: "L'Ecole 41 Chardonnay 2013",
#  331: "L'Ecole 41 Chardonnay 2014",
#  332: "L'Ecole 41 Chardonnay 2015",
#  333: "L'Ecole 41 Chardonnay 2016",
#  334: "L'Ecole 41 Chardonnay 2018",
#  335: "L'Ecole 41 Columbia Valley Cabernet Sauvignon 2007",
#  336: "L'Ecole 41 Columbia Valley Cabernet Sauvignon 2011",
#  337: "L'Ecole 41 Columbia Valley Cabernet Sauvignon 2012",
#  338: "L'Ecole 41 Columbia Valley Cabernet Sauvignon 2015",
#  339: "L'Ecole 41 Columbia Valley Merlot 2000",
#  340: "L'Ecole 41 Columbia Valley Merlot 2003",
#  341: "L'Ecole 41 Columbia Valley Merlot 2004",
#  342: "L'Ecole 41 Columbia Valley Merlot 2005",
#  343: "L'Ecole 41 Columbia Valley Merlot 2006",
#  344: "L'Ecole 41 Columbia Valley Merlot 2007",
#  345: "L'Ecole 41 Columbia Valley Merlot 2010",
#  346: "L'Ecole 41 Columbia Valley Merlot 2011",
#  347: "L'Ecole 41 Columbia Valley Merlot 2012",
#  348: "L'Ecole 41 Columbia Valley Merlot 2013",
#  349: "L'Ecole 41 Columbia Valley Merlot 2008",
#  350: "L'Ecole 41 Columbia Valley Merlot 2014",
#  351: "L'Ecole 41 Columbia Valley Merlot 2016",
#  352: "L'Ecole 41 Columbia Valley Syrah 2012",
#  353: "L'Ecole 41 Columbia Valley Syrah 2014",
#  354: "L'Ecole 41 Columbia Valley Syrah 2013",
#  355: "L'Ecole 41 Columbia Valley Syrah 2015",
#  356: "L'Ecole 41 Columbia Valley Syrah 2016",
#  357: "L'Ecole 41 Ferguson Estate Red 2012",
#  358: "L'Ecole 41 Ferguson Estate Red 2013",
#  359: "L'Ecole 41 Ferguson Estate Red 2014",
#  360: "L'Ecole 41 Ferguson Estate Red 2017",
#  361: "L'Ecole 41 Fries Vineyard Semillon 2002",
#  362: "L'Ecole 41 Fries Vineyard Semillon 2003",
#  363: "L'Ecole 41 Luminesce Seven Hills Vineyard 2007",
#  364: "L'Ecole 41 Luminesce Seven Hills Vineyard 2008",
#  365: "L'Ecole 41 Luminesce Seven Hills Vineyard 2009",
#  366: "L'Ecole 41 Luminesce Seven Hills Vineyard 2010",
#  367: "L'Ecole 41 Luminesce Seven Hills Vineyard 2012",
#  368: "L'Ecole 41 Luminesce Seven Hills Vineyard 2011",
#  369: "L'Ecole 41 Luminesce Seven Hills Vineyard 2013",
#  370: "L'Ecole 41 Luminesce Seven Hills Vineyard 2014",
#  371: "L'Ecole 41 Luminesce Seven Hills Vineyard 2016",
#  372: "L'Ecole 41 Old Vines Chenin Blanc 2011",
#  373: "L'Ecole 41 Old Vines Chenin Blanc 2010",
#  374: "L'Ecole 41 Old Vines Chenin Blanc 2014",
#  375: "L'Ecole 41 Old Vines Chenin Blanc 2013",
#  376: "L'Ecole 41 Old Vines Chenin Blanc 2012",
#  377: "L'Ecole 41 Old Vines Chenin Blanc 2015",
#  378: "L'Ecole 41 Old Vines Chenin Blanc 2016",
#  379: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2001",
#  380: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2006",
#  381: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2008",
#  382: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2007",
#  383: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2012",
#  384: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2013",
#  385: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2014",
#  386: "L'Ecole 41 Semillon 2005",
#  387: "L'Ecole 41 Semillon 2006",
#  388: "L'Ecole 41 Semillon 2007",
#  389: "L'Ecole 41 Semillon 2008",
#  390: "L'Ecole 41 Semillon 2010",
#  391: "L'Ecole 41 Semillon 2009",
#  392: "L'Ecole 41 Semillon 2012",
#  393: "L'Ecole 41 Semillon 2013",
#  394: "L'Ecole 41 Semillon 2015",
#  395: "L'Ecole 41 Semillon 2018",
#  396: "L'Ecole 41 Seven Hills Vineyard Estate Syrah 2001",
#  397: "L'Ecole 41 Seven Hills Vineyard Estate Syrah 2011",
#  398: "L'Ecole 41 Seven Hills Vineyard Estate Syrah 2014",
#  399: "L'Ecole 41 Seven Hills Vineyard Estate Syrah 2015",
#  400: "L'Ecole 41 Seven Hills Vineyard Merlot 2000",
#  401: "L'Ecole 41 Seven Hills Vineyard Merlot 2001",
#  402: "L'Ecole 41 Seven Hills Vineyard Merlot 2000",
#  403: "L'Ecole 41 Seven Hills Vineyard Merlot 2002",
#  404: "L'Ecole 41 Seven Hills Vineyard Merlot 2005",
#  405: "L'Ecole 41 Seven Hills Vineyard Merlot 2007",
#  406: "L'Ecole 41 Seven Hills Vineyard Perigee 2002",
#  407: "L'Ecole 41 Seven Hills Vineyard Perigee 2007",
#  408: "L'Ecole 41 Seven Hills Vineyard Perigee 2011",
#  409: "L'Ecole 41 Seven Hills Vineyard Perigee 2012",
#  410: "L'Ecole 41 Seven Hills Vineyard Perigee 2014",
#  411: "L'Ecole 41 Seven Hills Vineyard Perigee 2015",
#  412: "L'Ecole 41 Seven Hills Vineyard Perigee 2013",
#  413: "L'Ecole 41 Walla Voila Chenin Blanc 2009",
#  414: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 1998",
#  415: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2000",
#  416: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2001",
#  417: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2007",
#  418: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2009",
#  419: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2010",
#  420: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2011",
#  421: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2012",
#  422: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2013",
#  423: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2014",
#  424: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2016",
#  425: "L'Ecole 41 Walla Walla Valley Syrah 2003",
#  426: "L'Ecole 41 Walla Walla Valley Syrah 2004",
#  427: 'Ledge Catacombs Red Blend 2011',
#  428: 'Ledge Vineyard Drive Red Blend 2012',
#  429: 'Leese-Fitch Cabernet Sauvignon 2015',
#  430: 'Leese-Fitch Cabernet Sauvignon 2016',
#  431: 'Leese-Fitch Chardonnay 2015',
#  432: 'Leese-Fitch Chardonnay 2016',
#  433: 'Leese-Fitch Chardonnay 2017',
#  434: 'Leese-Fitch Pinot Noir 2016',
#  435: 'Leese-Fitch Sauvignon Blanc 2010',
#  436: 'Leese-Fitch Sauvignon Blanc 2015',
#  437: 'Leese-Fitch Sauvignon Blanc 2017',
#  438: 'Leese-Fitch Zinfandel 2016',
#  439: 'Leeuwin Estate Art Series Cabernet Sauvignon 1997',
#  440: 'Leeuwin Estate Art Series Cabernet Sauvignon 1998',
#  441: 'Leeuwin Estate Art Series Cabernet Sauvignon 1999',
#  442: 'Leeuwin Estate Art Series Cabernet Sauvignon 2001',
#  443: 'Leeuwin Estate Art Series Cabernet Sauvignon 2002',
#  444: 'Leeuwin Estate Art Series Cabernet Sauvignon 2003',
#  445: 'Leeuwin Estate Art Series Cabernet Sauvignon 2005',
#  446: 'Leeuwin Estate Art Series Cabernet Sauvignon 2006',
#  447: 'Leeuwin Estate Art Series Cabernet Sauvignon 2007',
#  448: 'Leeuwin Estate Art Series Cabernet Sauvignon 2008',
#  449: 'Leeuwin Estate Art Series Cabernet Sauvignon 2009',
#  450: 'Leeuwin Estate Art Series Cabernet Sauvignon 2010',
#  451: 'Leeuwin Estate Art Series Cabernet Sauvignon 2011',
#  452: 'Leeuwin Estate Art Series Cabernet Sauvignon 2013',
#  453: 'Leeuwin Estate Art Series Cabernet Sauvignon 2012',
#  454: 'Leeuwin Estate Art Series Cabernet Sauvignon 2015',
#  455: 'Leeuwin Estate Art Series Chardonnay 1998',
#  456: 'Leeuwin Estate Art Series Chardonnay 2000',
#  457: 'Leeuwin Estate Art Series Chardonnay 1999',
#  458: 'Leeuwin Estate Art Series Chardonnay 2002',
#  459: 'Leeuwin Estate Art Series Chardonnay 2003',
#  460: 'Leeuwin Estate Art Series Chardonnay 2004',
#  461: 'Leeuwin Estate Art Series Chardonnay 2001',
#  462: 'Leeuwin Estate Art Series Chardonnay 2005',
#  463: 'Leeuwin Estate Art Series Chardonnay 2006',
#  464: 'Leeuwin Estate Art Series Chardonnay 2007',
#  465: 'Leeuwin Estate Art Series Chardonnay 2010',
#  466: 'Leeuwin Estate Art Series Chardonnay 2011',
#  467: 'Leeuwin Estate Art Series Chardonnay 2013',
#  468: 'Leeuwin Estate Art Series Chardonnay 2009',
#  469: 'Leeuwin Estate Art Series Chardonnay 2012',
#  470: 'Leeuwin Estate Art Series Chardonnay 2014',
#  471: 'Leeuwin Estate Art Series Chardonnay 2008',
#  472: 'Leeuwin Estate Art Series Riesling 2001',
#  473: 'Leeuwin Estate Art Series Riesling 2006',
#  474: 'Leeuwin Estate Art Series Riesling 2004',
#  475: 'Leeuwin Estate Art Series Riesling 2008',
#  476: 'Leeuwin Estate Art Series Riesling 2010',
#  477: 'Leeuwin Estate Art Series Riesling 2002',
#  478: 'Leeuwin Estate Art Series Riesling 2011',
#  479: 'Leeuwin Estate Art Series Riesling 2012',
#  480: 'Leeuwin Estate Art Series Riesling 2013',
#  481: 'Leeuwin Estate Art Series Riesling 2014',
#  482: 'Leeuwin Estate Art Series Riesling 2015',
#  483: 'Leeuwin Estate Art Series Shiraz 1999',
#  484: 'Leeuwin Estate Art Series Shiraz 2000',
#  485: 'Leeuwin Estate Art Series Shiraz 2007',
#  486: 'Leeuwin Estate Art Series Shiraz 2009',
#  487: 'Leeuwin Estate Art Series Shiraz 2010',
#  488: 'Leeuwin Estate Art Series Shiraz 2012',
#  489: 'Leeuwin Estate Art Series Shiraz 2011',
#  490: 'Leeuwin Estate Art Series Shiraz 2013',
#  491: 'Leeuwin Estate Art Series Shiraz 2014',
#  492: 'Leeuwin Estate Margaret River Riesling 2000',
#  493: 'Leeuwin Estate Margaret River Riesling 1999',
#  494: 'Leeuwin Estate Prelude Cabernet Merlot (stained label) 1997',
#  495: 'Leeuwin Estate Prelude Vineyards Cabernet Sauvignon 2013',
#  496: 'Leeuwin Estate Prelude Vineyards Cabernet Sauvignon 2014',
#  497: 'Leeuwin Estate Prelude Vineyards Chardonnay 2001',
#  498: 'Leeuwin Estate Prelude Vineyards Chardonnay 2000',
#  499: 'Leeuwin Estate Prelude Vineyards Chardonnay 2004',
#  500: 'Leeuwin Estate Prelude Vineyards Chardonnay 2003',
#  501: 'Leeuwin Estate Prelude Vineyards Chardonnay 2006',
#  502: 'Leeuwin Estate Prelude Vineyards Chardonnay 2007',
#  503: 'Leeuwin Estate Prelude Vineyards Chardonnay 1999',
#  504: 'Leeuwin Estate Prelude Vineyards Chardonnay 2009',
#  505: 'Leeuwin Estate Prelude Vineyards Chardonnay 2010',
#  506: 'Leeuwin Estate Prelude Vineyards Chardonnay 2011',
#  507: 'Leeuwin Estate Prelude Vineyards Chardonnay 2012',
#  508: 'Leeuwin Estate Prelude Vineyards Chardonnay 2013',
#  509: 'Leeuwin Estate Prelude Vineyards Chardonnay 2014',
#  510: 'Leeuwin Estate Prelude Vineyards Chardonnay 2015',
#  511: 'Leeuwin Estate Prelude Vineyards Chardonnay 2018',
#  512: 'Leeuwin Estate Prelude Vineyards Chardonnay 2016',
#  513: 'Leeuwin Estate Siblings Sauvignon Blanc 2018',
#  514: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 1999',
#  515: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2002',
#  516: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2004',
#  517: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2011',
#  518: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2014',
#  519: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2015',
#  520: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2016',
#  521: 'Leeuwin Estate Siblings Shiraz 2003',
#  522: 'Leeuwin Estate Siblings Shiraz 2007',
#  523: 'Leeuwin Estate Siblings Shiraz 2004',
#  524: 'Leeuwin Estate Siblings Shiraz 2012',
#  525: 'Leeuwin Estate Siblings Shiraz 2014',
#  526: 'Leeuwin Estate Siblings Shiraz 2013',
#  527: "Left Coast Cellars Cali's Cuvee Pinot Noir 2006",
#  528: "Left Coast Cellars Cali's Cuvee Pinot Noir 2013",
#  529: "Left Coast Cellars Cali's Cuvee Pinot Noir 2014",
#  530: "Left Coast Cellars Cali's Cuvee Pinot Noir 2016",
#  531: 'Left Coast Cellars Latitude 45 Pinot Noir 2014',
#  532: 'Left Coast Cellars The Orchards Pinot Gris 2009',
#  533: 'Legacy Red 2013',
#  534: 'Legaris Crianza 2005',
#  535: 'Legaris Crianza 2009',
#  536: 'Legaris Crianza 2010',
#  537: 'Legaris Crianza 2012',
#  538: 'Lemelson Chardonnay Reserve 2012',
#  539: 'Lemelson Dry Riesling 2008',
#  540: 'Lemelson Dry Riesling 2009',
#  541: 'Lemelson Dry Riesling 2012',
#  542: 'Lemelson Jerome Reserve Pinot Noir 2012',
#  543: 'Lemelson Dry Riesling 2015',
#  544: 'Lemelson Meyer Vineyard Pinot Noir 2012',
#  545: 'Lemelson Meyer Vineyard Pinot Noir 2015',
#  546: 'Lemelson Stermer Vineyard Pinot Noir 2014',
#  547: "Lemelson Thea's Select Pinot Noir 2000",
#  548: "Lemelson Thea's Select Pinot Noir 2006",
#  549: "Lemelson Thea's Select Pinot Noir 2012",
#  550: "Lemelson Thea's Select Pinot Noir 2014",
#  551: "Lemelson Thea's Select Pinot Noir 2015",
#  552: 'Lengs and Cooter Shiraz The Victor 2005',
#  553: 'Lengs and Cooter Shiraz The Victor 2006',
#  554: 'Lengs and Cooter The Victor 2002',
#  555: 'Leo Steen Ascona Vineyard Cabernet Franc 2017',
#  556: 'Leo Steen Jurassic Vineyard Chenin Blanc 2012',
#  557: 'Leo Steen Jurassic Vineyard Chenin Blanc 2013',
#  558: 'Leo Steen Chardonnay 2015',
#  559: 'Leo Steen Jurassic Vineyard Chenin Blanc 2015',
#  560: 'Leo Steen Jurassic Vineyard Chenin Blanc 2016',
#  561: 'Leo Steen Peaberry Chenin Blanc 2016',
#  562: 'Leo Steen Provisor Vineyard Grenache 2016',
#  563: 'Leo Steen Provisor Vineyard Grenache 2015',
#  564: 'Leo Steen Saini Vineyard Chenin Blanc 2015',
#  565: 'Leo Steen Saini Vineyard Chenin Blanc 2016',
#  566: 'Leo Steen Scala Vineyard Syrah 2013',
#  567: 'Leone de Castris Primitivo di Manduria Villa Santera 2009',
#  568: 'Leone de Castris Salice Salentino Riserva 2006',
#  569: 'Leone de Castris Salice Salentino Riserva 2007',
#  570: 'Leone de Castris Salice Salentino Riserva 2010',
#  571: 'Leone de Castris Salice Salentino Riserva 2011',
#  572: 'Leone de Castris Salice Salentino Riserva 2014',
#  573: 'Leone de Castris Salice Salentino Riserva 2015',
#  574: 'Leonetti Cabernet Sauvignon (1.5 Liter Magnum) 2014',
#  575: 'Leone de Castris Verdeca Bianco Messapia 2009',
#  576: 'Leonetti Cabernet Sauvignon 1994',
#  577: 'Leonetti Cabernet Sauvignon 1995',
#  578: 'Leonetti Cabernet Sauvignon 1997',
#  579: 'Leonetti Cabernet Sauvignon 1998',
#  580: 'Leonetti Cabernet Sauvignon 2001',
#  581: 'Leonetti Cabernet Sauvignon 2000',
#  582: 'Leonetti Cabernet Sauvignon 2005',
#  583: 'Leonetti Cabernet Sauvignon 2010',
#  584: 'Leonetti Cabernet Sauvignon 2011',
#  585: 'Leonetti Cabernet Sauvignon 2012',
#  586: 'Leonetti Cabernet Sauvignon 2013',
#  587: 'Leonetti Cabernet Sauvignon 2014',
#  588: 'Leonetti Cabernet Sauvignon 2015',
#  589: 'Leonetti Cabernet Sauvignon (damaged label) 2007',
#  590: 'Leonetti Cabernet Sauvignon (damaged label) 2009',
#  591: 'Leonetti Merlot 1993',
#  592: 'Leonetti Merlot 1995',
#  593: 'Leonetti Merlot 1997',
#  594: 'Leonetti Merlot 1998',
#  595: 'Leonetti Merlot 1999',
#  596: 'Leonetti Merlot 2001',
#  597: 'Leonetti Merlot 2003',
#  598: 'Leonetti Merlot 2004',
#  599: 'Leonetti Merlot 2005',
#  600: 'Leonetti Merlot 2007',
#  601: 'Leonetti Merlot 2006',
#  602: 'Leonetti Merlot 2008',
#  603: 'Leonetti Merlot 2012',
#  604: 'Leonetti Merlot 2010',
#  605: 'Leonetti Merlot 2013',
#  606: 'Leonetti Merlot 2015',
#  607: 'Leonetti Merlot 2014',
#  608: 'Leonetti Merlot 2016',
#  609: 'Leonetti Merlot (loose foil capsule) 2000',
#  610: 'Leonetti Merlot (scuffed labels) 2011',
#  611: 'Leonetti Reserve 1998',
#  612: 'Leonetti Reserve 2002',
#  613: 'Leonetti Reserve 2005',
#  614: 'Leonetti Reserve 2000',
#  615: 'Leonetti Reserve 2006',
#  616: 'Leonetti Reserve 2011',
#  617: 'Leonetti Reserve 2012',
#  618: 'Leonetti Reserve 2014',
#  619: 'Leonetti Reserve 2013',
#  620: 'Leonetti Reserve 2015',
#  621: 'Leonetti Reserve (torn label) 2007',
#  622: 'Leonetti Reserve (torn label) 2008',
#  623: 'Leonetti Sangiovese 2005',
#  624: 'Leonetti Sangiovese 2000',
#  625: 'Leonetti Sangiovese 2006',
#  626: 'Leonetti Sangiovese 2007',
#  627: 'Leonetti Sangiovese 2008',
#  628: 'Leonetti Sangiovese 2009',
#  629: 'Leonetti Sangiovese 2011',
#  630: 'Leonetti Sangiovese 2010',
#  631: 'Leonetti Sangiovese 2013',
#  632: 'Leonetti Sangiovese 2012',
#  633: 'Leonetti Sangiovese 2014',
#  634: 'Leonetti Seven Hills Vineyard Reserve Cabernet Sauvignon 1996',
#  635: 'Les Alexandrins Cornas 2016',
#  636: 'Les Alexandrins Domaine Crozes-Hermitage 2016',
#  637: 'Les Alexandrins Domaine Saint-Joseph 2015',
#  638: 'Les Alexandrins Domaine Saint-Joseph 2016',
#  639: 'Les Alexandrins Maison Crozes-Hermitage 2016',
#  640: 'Les Alexandrins Syrah 2018',
#  641: "Les Alexandrins Terrasses de l'Eridan Cotes du Rhone Blanc 2017",
#  642: "Les Alexandrins Terrasses de l'Eridan Cotes du Rhone Rouge 2017",
#  643: 'Les Asteries 2005',
#  644: 'Les Asteries 2007',
#  645: 'Les Asteries 2008',
#  646: 'Les Asteries 2009',
#  647: 'Les Asteries 2011',
#  648: 'Les Asteries 2010',
#  649: "Les Clefs d'Or Les Craus Centenaires 2015",
#  650: "Les Clefs d'Or Les Craus Centenaires 2009",
#  651: "Les Clefs d'Or Les Craus Centenaires 2010",
#  652: 'Les Cretes Coteau La Tour 2008',
#  653: 'Les Cretes Le Sommet Nebbiolo 2016',
#  654: 'Les Cretes Les Abeilles 2006',
#  655: "Les Cretes Valle d'Aosta Chardonnay 2010",
#  656: "Les Cretes Valle d'Aosta Cuvee Bois Chardonnay 2016",
#  657: 'Les Forts de Latour 1996',
#  658: 'Les Forts de Latour 1999',
#  659: 'Les Forts de Latour 2000',
#  660: 'Les Forts de Latour 2001',
#  661: 'Les Forts de Latour 2005',
#  662: 'Les Forts de Latour 2008',
#  663: 'Les Forts de Latour 2009',
#  664: 'Les Garrigues Cotes du Rhone 2017',
#  665: 'Les Halos de Jupiter Chateauneuf-du-Pape 2009',
#  666: 'Les Halos de Jupiter Chateauneuf-du-Pape Adrastee 2009',
#  667: 'Les Halos de Jupiter Cotes du Rhone 2010',
#  668: 'Les Hauts de Lagarde Bordeaux Blanc 2013',
#  669: "Les Quatre Tours Coteaux d'Aix en Provence 2016",
#  670: "Les Vignerons d'Estezargues La Granacha Cotes du Rhone Villages Signargues 2008",
#  671: "Les Vignerons d'Estezargues La Granacha Cotes du Rhone Villages Signargues 2009",
#  672: 'Les Vignerons de Tautavel Cotes du Roussillon Villages Tautavel Silex 2012',
#  673: "Les Vignerons d'Estezargues La Granacha Cotes du Rhone Villages Signargues 2007",
#  674: "Les Vins Breban L'Opale de La Presqu'ile de St-Tropez Provence 2012",
#  675: 'Les Vignes Oubliées Coteaux du Languedoc Terrasses du Larzac 2014',
#  676: "L'Esprit de Chevalier Pessac Leognan 2000",
#  677: 'Leth Steinagrund Gruner Veltliner 2007',
#  678: 'Leth Steinagrund Gruner Veltliner 2008',
#  679: 'Leth Steinagrund Gruner Veltliner 2010',
#  680: 'Leth Steinagrund Gruner Veltliner 2012',
#  681: 'Leth Steinagrund Gruner Veltliner 2015',
#  682: 'Leth Steinagrund Gruner Veltliner 2016',
#  683: 'Leth Steinagrund Gruner Veltliner 2017',
#  684: 'Levendi River South Ranch Pinot Noir 2013',
#  685: 'Levendi Stagecoach Cabernet Sauvignon 2008',
#  686: 'Levendi Sweeney Ranch Chardonnay 2010',
#  687: 'Levet La Chavaroche Cote Rotie 2013',
#  688: 'Levet Les Journaries Cote Rotie 2010',
#  689: 'Leviathan (1.5 Liter Magnum) 2016',
#  690: 'Leviathan 2010',
#  691: 'Leviathan 2011',
#  692: 'Levy & McClellan Proprietary Red 2004',
#  693: 'Levy & McClellan Proprietary Red 2005',
#  694: 'Lewelling Cabernet Sauvignon 2000',
#  695: 'Lewelling Cabernet Sauvignon 2005',
#  696: 'Lewelling Cabernet Sauvignon 2001',
#  697: 'Lewelling Cabernet Sauvignon 2006',
#  698: 'Lewelling Cabernet Sauvignon 2007',
#  699: 'Lewelling Cabernet Sauvignon 2009',
#  700: 'Lewelling Cabernet Sauvignon 2010',
#  701: 'Lewelling Cabernet Sauvignon 2012',
#  702: 'Lewelling Wight Vineyard Cabernet Sauvignon 2003',
#  703: 'Lewelling Wight Vineyard Cabernet Sauvignon 2005',
#  704: 'Lewelling Wight Vineyard Cabernet Sauvignon 2006',
#  705: 'Lewelling Wight Vineyard Cabernet Sauvignon 2009',
#  706: 'Lewelling Wight Vineyard Cabernet Sauvignon 2008',
#  707: 'Lewelling Wight Vineyard Cabernet Sauvignon 2007',
#  708: 'Lewelling Wight Vineyard Cabernet Sauvignon 2010',
#  709: "Lewis Cellars Alec's Blend Red 2002",
#  710: "Lewis Cellars Alec's Blend Red 2003",
#  711: "Lewis Cellars Alec's Blend Red 2007",
#  712: "Lewis Cellars Alec's Blend Red 2009",
#  713: "Lewis Cellars Alec's Blend Red 2005",
#  714: "Lewis Cellars Alec's Blend Red 2010",
#  715: "Lewis Cellars Alec's Blend Red 2014",
#  716: "Lewis Cellars Alec's Blend Red 2013",
#  717: "Lewis Cellars Alec's Blend Red 2017",
#  718: 'Lewis Cellars Barcaglia Lane Chardonnay 2006',
#  719: 'Lewis Cellars Barcaglia Lane Chardonnay 2008',
#  720: 'Lewis Cellars Barcaglia Lane Chardonnay 2009',
#  721: 'Lewis Cellars Barcaglia Lane Chardonnay 2015',
#  722: 'Lewis Cellars Barcaglia Lane Chardonnay 2014',
#  723: 'Lewis Cellars Barcaglia Lane Chardonnay 2017',
#  724: 'Lewis Cellars Cabernet Sauvignon 2002',
#  725: 'Lewis Cellars Cabernet Sauvignon 2004',
#  726: 'Lewis Cellars Cabernet Sauvignon 2005',
#  727: 'Lewis Cellars Cabernet Sauvignon 2012',
#  728: 'Lewis Cellars Cabernet Sauvignon 2015',
#  729: 'Lewis Cellars Cabernet Sauvignon 2014',
#  730: 'Lewis Cellars Cabernet Sauvignon 2013',
#  731: 'Lewis Cellars Cabernet Sauvignon 2017',
#  732: 'Lewis Cellars Cuvee L 2005',
#  733: 'Lewis Cellars Cuvee L 2006',
#  734: 'Lewis Cellars Cuvee L Cabernet Sauvignon 2014',
#  735: 'Lewis Cellars Cuvee L Cabernet Sauvignon 2015',
#  736: 'Lewis Cellars Hillstone Vineyard Cabernet Sauvignon 2014',
#  737: 'Lewis Cellars Hudson Vineyards Syrah 2006',
#  738: "Lewis Cellars Mason's Cabernet Sauvignon 2003",
#  739: "Lewis Cellars Mason's Cabernet Sauvignon 2015",
#  740: "Lewis Cellars Mason's Cabernet Sauvignon 2018",
#  741: 'Lewis Cellars Merlot 2000',
#  742: 'Lewis Cellars Napa Valley Chardonnay 2008',
#  743: 'Lewis Cellars Napa Valley Chardonnay 2015',
#  744: 'Lewis Cellars Napa Valley Chardonnay 2014',
#  745: 'Lewis Cellars Napa Valley Chardonnay 2016',
#  746: 'Lewis Cellars Napa Valley Syrah 2006',
#  747: 'Lewis Cellars Napa Valley Syrah 2007',
#  748: 'Lewis Cellars Reserve Cabernet Sauvignon (1.5 Liter Magnum) 2011',
#  749: 'Lewis Cellars Reserve Cabernet Sauvignon (1.5 Liter Magnum) 2016',
#  750: 'Lewis Cellars Reserve Cabernet Sauvignon (1.5L Magnum) 2004',
#  751: 'Lewis Cellars Reserve Cabernet Sauvignon 1995',
#  752: 'Lewis Cellars Reserve Cabernet Sauvignon 2000',
#  753: 'Lewis Cellars Reserve Cabernet Sauvignon 2005',
#  754: 'Lewis Cellars Reserve Cabernet Sauvignon 2006',
#  755: 'Lewis Cellars Reserve Cabernet Sauvignon 2007',
#  756: 'Lewis Cellars Reserve Cabernet Sauvignon 2008',
#  757: 'Lewis Cellars Reserve Cabernet Sauvignon 2009',
#  758: 'Lewis Cellars Reserve Cabernet Sauvignon 2010',
#  759: 'Lewis Cellars Reserve Cabernet Sauvignon 2011',
#  760: 'Lewis Cellars Reserve Cabernet Sauvignon 2015',
#  761: 'Lewis Cellars Reserve Cabernet Sauvignon 2014',
#  762: 'Lewis Cellars Reserve Cabernet Sauvignon 2016',
#  763: 'Lewis Cellars Reserve Cabernet Sauvignon (scuffed labels) 2012',
#  764: 'Lewis Cellars Reserve Chardonnay 2008',
#  765: 'Lewis Cellars Reserve Chardonnay 2015',
#  766: 'Lewis Cellars Reserve Chardonnay 2018',
#  767: 'Lewis Cellars Reserve Chardonnay 2017',
#  768: 'Lewis Cellars Reserve Merlot 1995',
#  769: 'Lewis Cellars Sauvignon Blanc 2016',
#  770: 'Lewis Cellars Sauvignon Blanc 2018',
#  771: 'Lewis Cellars Sonoma Chardonnay 2014',
#  772: 'Lewis Cellars Sonoma Chardonnay 2015',
#  773: 'Lewis Cellars Sonoma Chardonnay 2017',
#  774: 'Lewis Cellars Sonoma Valley Chardonnay 2008',
#  775: "Lewis Cellars Syrah Ethan's Blend 2005",
#  776: "Lewis Cellars Syrah Ethan's Blend 2014",
#  777: "Lewis Cellars Syrah Ethan's Blend 2009",
#  778: 'Lexington Apex Red 2011',
#  779: 'Lexington Gist Ranch Cabernet Sauvignon 2011'}

# %%
# if you want to get the values of a row, you can use the index of the row as a key, but you have to use it for every column you need. For example:
print(dict_data['name'][0], # get the value of the 'name' column for the row with index 0
dict_data['rating'][0], # get the value of the 'rating' column for the row with index 0
dict_data['region'][0], # get the value of the 'region' column for the row with index 0
)
# Out:
# Laurenz V Charming Gruner Veltliner 2013 90.0 Kamptal, Austria

# %%
dict_data['variety']
# Out:
# {0: 'White Wine',
#  1: 'White Wine',
#  2: 'White Wine',
#  3: 'White Wine',
#  4: 'White Wine',
#  5: 'White Wine',
#  6: 'Red Wine',
#  7: 'Red Wine',
#  8: 'White Wine',
#  9: 'Red Wine',
#  10: 'Red Wine',
#  11: 'Red Wine',
#  12: 'Red Wine',
#  13: 'Red Wine',
#  14: 'White Wine',
#  15: 'White Wine',
#  16: 'White Wine',
#  17: 'Red Wine',
#  18: 'White Wine',
#  19: 'White Wine',
#  20: 'Red Wine',
#  21: 'Red Wine',
#  22: 'Red Wine',
#  23: 'Red Wine',
#  24: 'Red Wine',
#  25: 'Red Wine',
#  26: 'Red Wine',
#  27: 'Red Wine',
#  28: 'Red Wine',
#  29: 'Red Wine',
#  30: 'Red Wine',
#  31: 'Red Wine',
#  32: 'Red Wine',
#  33: 'Red Wine',
#  34: 'Red Wine',
#  35: 'Red Wine',
#  36: 'Red Wine',
#  37: 'Red Wine',
#  38: 'Red Wine',
#  39: 'Red Wine',
#  40: 'Red Wine',
#  41: 'Red Wine',
#  42: 'Red Wine',
#  43: 'Red Wine',
#  44: 'Red Wine',
#  45: 'Red Wine',
#  46: 'Red Wine',
#  47: 'Red Wine',
#  48: 'Red Wine',
#  49: 'Red Wine',
#  50: 'Red Wine',
#  51: 'Red Wine',
#  52: 'Red Wine',
#  53: 'Red Wine',
#  54: 'Red Wine',
#  55: 'Red Wine',
#  56: 'Red Wine',
#  57: 'Red Wine',
#  58: 'Red Wine',
#  59: 'Red Wine',
#  60: 'Red Wine',
#  61: 'Red Wine',
#  62: 'Red Wine',
#  63: 'Red Wine',
#  64: 'Red Wine',
#  65: 'Red Wine',
#  66: 'White Wine',
#  67: 'Red Wine',
#  68: 'Red Wine',
#  69: 'Red Wine',
#  70: 'Red Wine',
#  71: 'Red Wine',
#  72: 'Red Wine',
#  73: 'Red Wine',
#  74: 'Red Wine',
#  75: 'Red Wine',
#  76: 'White Wine',
#  77: 'White Wine',
#  78: 'Red Wine',
#  79: 'White Wine',
#  80: 'Red Wine',
#  81: 'White Wine',
#  82: 'Red Wine',
#  83: 'Red Wine',
#  84: 'Red Wine',
#  85: 'Red Wine',
#  86: 'Red Wine',
#  87: 'Red Wine',
#  88: 'Red Wine',
#  89: 'Red Wine',
#  90: 'White Wine',
#  91: 'Red Wine',
#  92: 'Red Wine',
#  93: 'White Wine',
#  94: 'Sparkling & Champagne',
#  95: 'Red Wine',
#  96: 'Red Wine',
#  97: 'Red Wine',
#  98: 'Red Wine',
#  99: 'Red Wine',
#  100: 'Red Wine',
#  101: 'Red Wine',
#  102: 'Red Wine',
#  103: 'Red Wine',
#  104: 'Red Wine',
#  105: 'Red Wine',
#  106: 'Red Wine',
#  107: 'Red Wine',
#  108: 'Red Wine',
#  109: 'Red Wine',
#  110: 'Red Wine',
#  111: 'Red Wine',
#  112: 'White Wine',
#  113: 'Red Wine',
#  114: 'Red Wine',
#  115: 'Red Wine',
#  116: 'Red Wine',
#  117: 'Red Wine',
#  118: 'Red Wine',
#  119: 'Red Wine',
#  120: 'Red Wine',
#  121: 'Red Wine',
#  122: 'Red Wine',
#  123: 'Red Wine',
#  124: 'Red Wine',
#  125: 'Red Wine',
#  126: 'Red Wine',
#  127: 'Red Wine',
#  128: 'White Wine',
#  129: 'White Wine',
#  130: 'Red Wine',
#  131: 'Red Wine',
#  132: 'Sparkling & Champagne',
#  133: 'Sparkling & Champagne',
#  134: 'Sparkling & Champagne',
#  135: 'Red Wine',
#  136: 'Red Wine',
#  137: 'Red Wine',
#  138: 'Red Wine',
#  139: 'Red Wine',
#  140: 'Red Wine',
#  141: 'Red Wine',
#  142: 'Red Wine',
#  143: 'Red Wine',
#  144: 'Red Wine',
#  145: 'White Wine',
#  146: 'White Wine',
#  147: 'White Wine',
#  148: 'Red Wine',
#  149: 'Red Wine',
#  150: 'Red Wine',
#  151: 'Red Wine',
#  152: 'Red Wine',
#  153: 'White Wine',
#  154: 'White Wine',
#  155: 'Red Wine',
#  156: 'Red Wine',
#  157: 'Red Wine',
#  158: 'Red Wine',
#  159: 'Sparkling & Champagne',
#  160: 'Sparkling & Champagne',
#  161: 'Red Wine',
#  162: 'Red Wine',
#  163: 'Red Wine',
#  164: 'Red Wine',
#  165: 'Red Wine',
#  166: 'Red Wine',
#  167: 'Red Wine',
#  168: 'Red Wine',
#  169: 'Red Wine',
#  170: 'Red Wine',
#  171: 'Red Wine',
#  172: 'Red Wine',
#  173: 'Red Wine',
#  174: 'Red Wine',
#  175: 'Red Wine',
#  176: 'Red Wine',
#  177: 'Red Wine',
#  178: 'Red Wine',
#  179: 'Red Wine',
#  180: 'Red Wine',
#  181: 'Red Wine',
#  182: 'Red Wine',
#  183: 'Red Wine',
#  184: 'Red Wine',
#  185: 'Red Wine',
#  186: 'Red Wine',
#  187: 'Red Wine',
#  188: 'Red Wine',
#  189: 'Red Wine',
#  190: 'Red Wine',
#  191: 'Red Wine',
#  192: 'Red Wine',
#  193: 'Red Wine',
#  194: 'Red Wine',
#  195: 'Red Wine',
#  196: 'Red Wine',
#  197: 'Red Wine',
#  198: 'Red Wine',
#  199: 'Red Wine',
#  200: 'Red Wine',
#  201: 'White Wine',
#  202: 'White Wine',
#  203: 'White Wine',
#  204: 'White Wine',
#  205: 'White Wine',
#  206: 'Red Wine',
#  207: 'Red Wine',
#  208: 'Red Wine',
#  209: 'Red Wine',
#  210: 'Red Wine',
#  211: 'Red Wine',
#  212: 'Red Wine',
#  213: 'Red Wine',
#  214: 'Red Wine',
#  215: 'Red Wine',
#  216: 'Red Wine',
#  217: 'Red Wine',
#  218: 'Red Wine',
#  219: 'Red Wine',
#  220: 'Red Wine',
#  221: 'Red Wine',
#  222: 'Red Wine',
#  223: 'Red Wine',
#  224: 'Red Wine',
#  225: 'Red Wine',
#  226: 'Red Wine',
#  227: 'Red Wine',
#  228: 'White Wine',
#  229: 'White Wine',
#  230: 'White Wine',
#  231: 'White Wine',
#  232: 'White Wine',
#  233: 'Red Wine',
#  234: 'Red Wine',
#  235: 'Red Wine',
#  236: 'Red Wine',
#  237: 'Red Wine',
#  238: 'Red Wine',
#  239: 'Red Wine',
#  240: 'Red Wine',
#  241: 'Red Wine',
#  242: 'Red Wine',
#  243: 'Pink and Rosé',
#  244: 'Red Wine',
#  245: 'Red Wine',
#  246: 'Red Wine',
#  247: 'White Wine',
#  248: 'White Wine',
#  249: 'White Wine',
#  250: 'Pink and Rosé',
#  251: 'Red Wine',
#  252: 'Red Wine',
#  253: 'Red Wine',
#  254: nan,
#  255: 'Red Wine',
#  256: 'Red Wine',
#  257: 'Red Wine',
#  258: 'Red Wine',
#  259: 'Red Wine',
#  260: 'Red Wine',
#  261: 'Red Wine',
#  262: 'Red Wine',
#  263: 'Red Wine',
#  264: 'Red Wine',
#  265: 'Red Wine',
#  266: 'Red Wine',
#  267: 'Red Wine',
#  268: 'Red Wine',
#  269: 'Red Wine',
#  270: 'Red Wine',
#  271: 'Red Wine',
#  272: 'Red Wine',
#  273: 'Red Wine',
#  274: 'Red Wine',
#  275: 'Red Wine',
#  276: 'Red Wine',
#  277: 'White Wine',
#  278: 'White Wine',
#  279: 'Red Wine',
#  280: 'Red Wine',
#  281: 'Red Wine',
#  282: 'Red Wine',
#  283: 'Red Wine',
#  284: 'Red Wine',
#  285: nan,
#  286: 'Collectible',
#  287: nan,
#  288: 'Red Wine',
#  289: 'Red Wine',
#  290: 'Red Wine',
#  291: 'Red Wine',
#  292: 'Red Wine',
#  293: 'Red Wine',
#  294: 'Red Wine',
#  295: 'White Wine',
#  296: 'White Wine',
#  297: 'White Wine',
#  298: 'White Wine',
#  299: 'Red Wine',
#  300: 'Red Wine',
#  301: 'Red Wine',
#  302: 'Red Wine',
#  303: 'Red Wine',
#  304: 'White Wine',
#  305: 'White Wine',
#  306: 'White Wine',
#  307: 'White Wine',
#  308: 'Red Wine',
#  309: 'Red Wine',
#  310: 'Red Wine',
#  311: 'Red Wine',
#  312: 'Red Wine',
#  313: 'Red Wine',
#  314: 'Red Wine',
#  315: 'Red Wine',
#  316: 'Red Wine',
#  317: 'Red Wine',
#  318: 'Red Wine',
#  319: 'Red Wine',
#  320: 'Red Wine',
#  321: 'White Wine',
#  322: 'White Wine',
#  323: 'White Wine',
#  324: 'White Wine',
#  325: 'White Wine',
#  326: 'White Wine',
#  327: 'White Wine',
#  328: 'White Wine',
#  329: 'White Wine',
#  330: 'White Wine',
#  331: 'White Wine',
#  332: 'White Wine',
#  333: 'White Wine',
#  334: 'White Wine',
#  335: 'Red Wine',
#  336: 'Red Wine',
#  337: 'Red Wine',
#  338: 'Red Wine',
#  339: 'Red Wine',
#  340: 'Red Wine',
#  341: 'Red Wine',
#  342: 'Red Wine',
#  343: 'Red Wine',
#  344: 'Red Wine',
#  345: 'Red Wine',
#  346: 'Red Wine',
#  347: 'Red Wine',
#  348: 'Red Wine',
#  349: 'Red Wine',
#  350: 'Red Wine',
#  351: 'Red Wine',
#  352: 'Red Wine',
#  353: 'Red Wine',
#  354: 'Red Wine',
#  355: 'Red Wine',
#  356: 'Red Wine',
#  357: 'Red Wine',
#  358: 'Red Wine',
#  359: 'Red Wine',
#  360: 'Red Wine',
#  361: 'White Wine',
#  362: 'White Wine',
#  363: 'White Wine',
#  364: 'White Wine',
#  365: 'White Wine',
#  366: 'White Wine',
#  367: 'White Wine',
#  368: 'White Wine',
#  369: 'White Wine',
#  370: 'White Wine',
#  371: 'White Wine',
#  372: 'White Wine',
#  373: 'White Wine',
#  374: 'White Wine',
#  375: 'White Wine',
#  376: 'White Wine',
#  377: 'White Wine',
#  378: 'White Wine',
#  379: 'Red Wine',
#  380: 'Red Wine',
#  381: 'Red Wine',
#  382: 'Red Wine',
#  383: 'Red Wine',
#  384: 'Red Wine',
#  385: 'Red Wine',
#  386: 'White Wine',
#  387: 'White Wine',
#  388: 'White Wine',
#  389: 'White Wine',
#  390: 'White Wine',
#  391: 'White Wine',
#  392: 'White Wine',
#  393: 'White Wine',
#  394: 'White Wine',
#  395: 'White Wine',
#  396: 'Red Wine',
#  397: 'Red Wine',
#  398: 'Red Wine',
#  399: 'Red Wine',
#  400: 'Red Wine',
#  401: 'Red Wine',
#  402: 'Red Wine',
#  403: 'Red Wine',
#  404: 'Red Wine',
#  405: 'Red Wine',
#  406: 'Red Wine',
#  407: 'Red Wine',
#  408: 'Red Wine',
#  409: 'Red Wine',
#  410: 'Red Wine',
#  411: 'Red Wine',
#  412: 'Red Wine',
#  413: 'White Wine',
#  414: 'Red Wine',
#  415: 'Red Wine',
#  416: 'Red Wine',
#  417: 'Red Wine',
#  418: 'Red Wine',
#  419: 'Red Wine',
#  420: 'Red Wine',
#  421: 'Red Wine',
#  422: 'Red Wine',
#  423: 'Red Wine',
#  424: 'Red Wine',
#  425: 'Red Wine',
#  426: 'Red Wine',
#  427: 'Red Wine',
#  428: 'Red Wine',
#  429: 'Red Wine',
#  430: 'Red Wine',
#  431: 'White Wine',
#  432: 'White Wine',
#  433: 'White Wine',
#  434: 'Red Wine',
#  435: 'White Wine',
#  436: 'White Wine',
#  437: 'White Wine',
#  438: 'Red Wine',
#  439: 'Red Wine',
#  440: 'Red Wine',
#  441: 'Red Wine',
#  442: 'Red Wine',
#  443: 'Red Wine',
#  444: 'Red Wine',
#  445: 'Red Wine',
#  446: 'Red Wine',
#  447: 'Red Wine',
#  448: 'Red Wine',
#  449: 'Red Wine',
#  450: 'Red Wine',
#  451: 'Red Wine',
#  452: 'Red Wine',
#  453: 'Red Wine',
#  454: 'Red Wine',
#  455: 'White Wine',
#  456: 'White Wine',
#  457: 'White Wine',
#  458: 'White Wine',
#  459: 'White Wine',
#  460: 'White Wine',
#  461: 'White Wine',
#  462: 'White Wine',
#  463: 'White Wine',
#  464: 'White Wine',
#  465: 'White Wine',
#  466: 'White Wine',
#  467: 'White Wine',
#  468: 'White Wine',
#  469: 'White Wine',
#  470: 'White Wine',
#  471: 'White Wine',
#  472: 'White Wine',
#  473: 'White Wine',
#  474: 'White Wine',
#  475: 'White Wine',
#  476: 'White Wine',
#  477: 'White Wine',
#  478: 'White Wine',
#  479: 'White Wine',
#  480: 'White Wine',
#  481: 'White Wine',
#  482: 'White Wine',
#  483: 'Red Wine',
#  484: 'Red Wine',
#  485: 'Red Wine',
#  486: 'Red Wine',
#  487: 'Red Wine',
#  488: 'Red Wine',
#  489: 'Red Wine',
#  490: 'Red Wine',
#  491: 'Red Wine',
#  492: 'White Wine',
#  493: 'White Wine',
#  494: 'Red Wine',
#  495: 'Red Wine',
#  496: 'Red Wine',
#  497: 'White Wine',
#  498: 'White Wine',
#  499: 'White Wine',
#  500: 'White Wine',
#  501: 'White Wine',
#  502: 'White Wine',
#  503: 'White Wine',
#  504: 'White Wine',
#  505: 'White Wine',
#  506: 'White Wine',
#  507: 'White Wine',
#  508: 'White Wine',
#  509: 'White Wine',
#  510: 'White Wine',
#  511: 'White Wine',
#  512: 'White Wine',
#  513: 'White Wine',
#  514: 'White Wine',
#  515: 'White Wine',
#  516: 'White Wine',
#  517: 'White Wine',
#  518: 'White Wine',
#  519: 'White Wine',
#  520: 'White Wine',
#  521: 'Red Wine',
#  522: 'Red Wine',
#  523: 'Red Wine',
#  524: 'Red Wine',
#  525: 'Red Wine',
#  526: 'Red Wine',
#  527: 'Red Wine',
#  528: 'Red Wine',
#  529: 'Red Wine',
#  530: 'Red Wine',
#  531: 'Red Wine',
#  532: 'White Wine',
#  533: 'Red Wine',
#  534: 'Red Wine',
#  535: 'Red Wine',
#  536: 'Red Wine',
#  537: 'Red Wine',
#  538: 'White Wine',
#  539: 'White Wine',
#  540: 'White Wine',
#  541: 'White Wine',
#  542: 'Red Wine',
#  543: 'White Wine',
#  544: 'Red Wine',
#  545: 'Red Wine',
#  546: 'Red Wine',
#  547: 'Red Wine',
#  548: 'Red Wine',
#  549: 'Red Wine',
#  550: 'Red Wine',
#  551: 'Red Wine',
#  552: 'Red Wine',
#  553: 'Red Wine',
#  554: 'Red Wine',
#  555: 'Red Wine',
#  556: 'White Wine',
#  557: 'White Wine',
#  558: 'White Wine',
#  559: 'White Wine',
#  560: 'White Wine',
#  561: 'White Wine',
#  562: 'Red Wine',
#  563: 'Red Wine',
#  564: 'White Wine',
#  565: 'White Wine',
#  566: 'Red Wine',
#  567: 'Red Wine',
#  568: 'Red Wine',
#  569: 'Red Wine',
#  570: 'Red Wine',
#  571: 'Red Wine',
#  572: 'Red Wine',
#  573: 'Red Wine',
#  574: 'Red Wine',
#  575: 'White Wine',
#  576: 'Red Wine',
#  577: 'Red Wine',
#  578: 'Red Wine',
#  579: 'Red Wine',
#  580: 'Red Wine',
#  581: 'Red Wine',
#  582: 'Red Wine',
#  583: 'Red Wine',
#  584: 'Red Wine',
#  585: 'Red Wine',
#  586: 'Red Wine',
#  587: 'Red Wine',
#  588: 'Red Wine',
#  589: 'Red Wine',
#  590: 'Red Wine',
#  591: 'Red Wine',
#  592: 'Red Wine',
#  593: 'Red Wine',
#  594: 'Red Wine',
#  595: 'Red Wine',
#  596: 'Red Wine',
#  597: 'Red Wine',
#  598: 'Red Wine',
#  599: 'Red Wine',
#  600: 'Red Wine',
#  601: 'Red Wine',
#  602: 'Red Wine',
#  603: 'Red Wine',
#  604: 'Red Wine',
#  605: 'Red Wine',
#  606: 'Red Wine',
#  607: 'Red Wine',
#  608: 'Red Wine',
#  609: 'Red Wine',
#  610: 'Red Wine',
#  611: 'Red Wine',
#  612: 'Red Wine',
#  613: 'Red Wine',
#  614: 'Red Wine',
#  615: 'Red Wine',
#  616: 'Red Wine',
#  617: 'Red Wine',
#  618: 'Red Wine',
#  619: 'Red Wine',
#  620: 'Red Wine',
#  621: 'Red Wine',
#  622: 'Red Wine',
#  623: 'Red Wine',
#  624: 'Red Wine',
#  625: 'Red Wine',
#  626: 'Red Wine',
#  627: 'Red Wine',
#  628: 'Red Wine',
#  629: 'Red Wine',
#  630: 'Red Wine',
#  631: 'Red Wine',
#  632: 'Red Wine',
#  633: 'Red Wine',
#  634: 'Red Wine',
#  635: 'Red Wine',
#  636: 'Red Wine',
#  637: 'Red Wine',
#  638: 'Red Wine',
#  639: 'Red Wine',
#  640: 'Red Wine',
#  641: 'White Wine',
#  642: 'Red Wine',
#  643: 'Red Wine',
#  644: 'Red Wine',
#  645: 'Red Wine',
#  646: 'Red Wine',
#  647: 'Red Wine',
#  648: 'Red Wine',
#  649: 'Red Wine',
#  650: 'Red Wine',
#  651: 'Red Wine',
#  652: 'Red Wine',
#  653: 'Red Wine',
#  654: 'White Wine',
#  655: 'White Wine',
#  656: 'White Wine',
#  657: 'Red Wine',
#  658: 'Red Wine',
#  659: 'Red Wine',
#  660: 'Red Wine',
#  661: 'Red Wine',
#  662: 'Red Wine',
#  663: 'Red Wine',
#  664: 'Red Wine',
#  665: 'Red Wine',
#  666: 'Red Wine',
#  667: 'Red Wine',
#  668: 'White Wine',
#  669: 'Pink and Rosé',
#  670: 'Red Wine',
#  671: 'Red Wine',
#  672: 'Red Wine',
#  673: 'Red Wine',
#  674: 'Pink and Rosé',
#  675: 'Red Wine',
#  676: 'Red Wine',
#  677: 'White Wine',
#  678: 'White Wine',
#  679: 'White Wine',
#  680: 'White Wine',
#  681: 'White Wine',
#  682: 'White Wine',
#  683: 'White Wine',
#  684: 'Red Wine',
#  685: 'Red Wine',
#  686: 'White Wine',
#  687: 'Red Wine',
#  688: 'Red Wine',
#  689: 'Red Wine',
#  690: 'Red Wine',
#  691: 'Red Wine',
#  692: 'Red Wine',
#  693: 'Red Wine',
#  694: 'Red Wine',
#  695: 'Red Wine',
#  696: 'Red Wine',
#  697: 'Red Wine',
#  698: 'Red Wine',
#  699: 'Red Wine',
#  700: 'Red Wine',
#  701: 'Red Wine',
#  702: 'Red Wine',
#  703: 'Red Wine',
#  704: 'Red Wine',
#  705: 'Red Wine',
#  706: 'Red Wine',
#  707: 'Red Wine',
#  708: 'Red Wine',
#  709: 'Red Wine',
#  710: 'Red Wine',
#  711: 'Red Wine',
#  712: 'Red Wine',
#  713: 'Red Wine',
#  714: 'Red Wine',
#  715: 'Red Wine',
#  716: 'Red Wine',
#  717: 'Red Wine',
#  718: 'White Wine',
#  719: 'White Wine',
#  720: 'White Wine',
#  721: 'White Wine',
#  722: 'White Wine',
#  723: 'White Wine',
#  724: 'Red Wine',
#  725: 'Red Wine',
#  726: 'Red Wine',
#  727: 'Red Wine',
#  728: 'Red Wine',
#  729: 'Red Wine',
#  730: 'Red Wine',
#  731: 'Red Wine',
#  732: 'Red Wine',
#  733: 'Red Wine',
#  734: 'Red Wine',
#  735: 'Red Wine',
#  736: 'Red Wine',
#  737: 'Red Wine',
#  738: 'Red Wine',
#  739: 'Red Wine',
#  740: 'Red Wine',
#  741: 'Red Wine',
#  742: 'White Wine',
#  743: 'White Wine',
#  744: 'White Wine',
#  745: 'White Wine',
#  746: 'Red Wine',
#  747: 'Red Wine',
#  748: 'Red Wine',
#  749: 'Red Wine',
#  750: 'Red Wine',
#  751: 'Red Wine',
#  752: 'Red Wine',
#  753: 'Red Wine',
#  754: 'Red Wine',
#  755: 'Red Wine',
#  756: 'Red Wine',
#  757: 'Red Wine',
#  758: 'Red Wine',
#  759: 'Red Wine',
#  760: 'Red Wine',
#  761: 'Red Wine',
#  762: 'Red Wine',
#  763: 'Red Wine',
#  764: 'White Wine',
#  765: 'White Wine',
#  766: 'White Wine',
#  767: 'White Wine',
#  768: 'Red Wine',
#  769: 'White Wine',
#  770: 'White Wine',
#  771: 'White Wine',
#  772: 'White Wine',
#  773: 'White Wine',
#  774: 'White Wine',
#  775: 'Red Wine',
#  776: 'Red Wine',
#  777: 'Red Wine',
#  778: 'Red Wine',
#  779: 'Red Wine'}

# %%
ninetyplus_rating = {"name": [], "rate": []}
for index, rate in enumerate(dict_data['rating']):
    if rate >= 90 and rate <= 92:
        ninetyplus_rating['name'].append(dict_data['name'][index])
        ninetyplus_rating['rate'].append(rate)
        
with open("exercise.json", "w") as f:
    json.dump(ninetyplus_rating, f)

# %%
dict_data['region']
# Out:
# {0: 'Kamptal, Austria',
#  1: 'Kamptal, Austria',
#  2: 'Austria',
#  3: 'Austria',
#  4: 'Austria',
#  5: 'Austria',
#  6: 'El Dorado, Sierra Foothills, California',
#  7: 'Sierra Foothills, California',
#  8: 'Sierra Foothills, California',
#  9: 'El Dorado, Sierra Foothills, California',
#  10: 'El Dorado, Sierra Foothills, California',
#  11: 'El Dorado, Sierra Foothills, California',
#  12: 'El Dorado, Sierra Foothills, California',
#  13: 'El Dorado, Sierra Foothills, California',
#  14: 'El Dorado, Sierra Foothills, California',
#  15: 'El Dorado, Sierra Foothills, California',
#  16: 'El Dorado, Sierra Foothills, California',
#  17: 'El Dorado, Sierra Foothills, California',
#  18: 'El Dorado, Sierra Foothills, California',
#  19: 'El Dorado, Sierra Foothills, California',
#  20: 'California',
#  21: 'El Dorado, Sierra Foothills, California',
#  22: 'El Dorado, Sierra Foothills, California',
#  23: 'Knights Valley, Sonoma County, California',
#  24: 'Napa Valley, California',
#  25: 'Napa Valley, California',
#  26: 'Napa Valley, California',
#  27: 'Chateauneuf-du-Pape, Rhone, France',
#  28: 'Chateauneuf-du-Pape, Rhone, France',
#  29: 'Chateauneuf-du-Pape, Rhone, France',
#  30: 'Gigondas, Rhone, France',
#  31: 'Gigondas, Rhone, France',
#  32: 'Gigondas, Rhone, France',
#  33: 'Gigondas, Rhone, France',
#  34: 'Gigondas, Rhone, France',
#  35: 'Rasteau, Rhone, France',
#  36: 'Rasteau, Rhone, France',
#  37: 'Paso Robles, Central Coast, California',
#  38: 'Paso Robles, Central Coast, California',
#  39: 'Paso Robles, Central Coast, California',
#  40: 'Paso Robles, Central Coast, California',
#  41: 'Paso Robles, Central Coast, California',
#  42: 'Central Coast, California',
#  43: 'Paso Robles, Central Coast, California',
#  44: 'Paso Robles, Central Coast, California',
#  45: 'Paso Robles, Central Coast, California',
#  46: 'Paso Robles, Central Coast, California',
#  47: 'Paso Robles, Central Coast, California',
#  48: 'Paso Robles, Central Coast, California',
#  49: 'Central Coast, California',
#  50: 'Central Coast, California',
#  51: 'Paso Robles, Central Coast, California',
#  52: 'Paso Robles, Central Coast, California',
#  53: 'Central Coast, California',
#  54: 'Paso Robles, Central Coast, California',
#  55: 'Central Coast, California',
#  56: 'Paso Robles, Central Coast, California',
#  57: 'Paso Robles, Central Coast, California',
#  58: 'Central Coast, California',
#  59: 'Central Coast, California',
#  60: 'Central Coast, California',
#  61: 'Central Coast, California',
#  62: 'Paso Robles, Central Coast, California',
#  63: 'Willow Creek District, Paso Robles, Central Coast, California',
#  64: 'Willow Creek District, Paso Robles, Central Coast, California',
#  65: 'Paso Robles, Central Coast, California',
#  66: 'Eola-Amity Hills, Willamette Valley, Oregon',
#  67: 'Eola-Amity Hills, Willamette Valley, Oregon',
#  68: 'Yamhill-Carlton District, Willamette Valley, Oregon',
#  69: 'Dundee Hills, Willamette Valley, Oregon',
#  70: 'Willamette Valley, Oregon',
#  71: 'Willamette Valley, Oregon',
#  72: 'Portugal',
#  73: 'Portugal',
#  74: 'Paso Robles, Central Coast, California',
#  75: 'Paso Robles, Central Coast, California',
#  76: 'New Zealand',
#  77: 'Marlborough, New Zealand',
#  78: 'Marlborough, New Zealand',
#  79: 'Marlborough, New Zealand',
#  80: 'California',
#  81: 'Central Coast, California',
#  82: 'Spain',
#  83: 'Argentina',
#  84: 'Italy',
#  85: 'South Australia, Australia',
#  86: 'South Australia, Australia',
#  87: 'South Australia, Australia',
#  88: 'South Australia, Australia',
#  89: 'South Australia, Australia',
#  90: 'Central Coast, California',
#  91: 'Tuscany, Italy',
#  92: 'South Africa',
#  93: 'South Africa',
#  94: 'Champagne, France',
#  95: 'Willamette Valley, Oregon',
#  96: 'Willamette Valley, Oregon',
#  97: 'Willamette Valley, Oregon',
#  98: 'Willamette Valley, Oregon',
#  99: 'Willamette Valley, Oregon',
#  100: 'St. Emilion, Bordeaux, France',
#  101: 'St. Emilion, Bordeaux, France',
#  102: 'St. Emilion, Bordeaux, France',
#  103: 'St. Emilion, Bordeaux, France',
#  104: 'St. Emilion, Bordeaux, France',
#  105: 'St. Emilion, Bordeaux, France',
#  106: 'Sicily, Italy',
#  107: 'Sicily, Italy',
#  108: 'Sicily, Italy',
#  109: 'Sicily, Italy',
#  110: 'Sicily, Italy',
#  111: 'Sicily, Italy',
#  112: 'Sicily, Italy',
#  113: 'Sicily, Italy',
#  114: 'Rhone, France',
#  115: 'Montalcino, Tuscany, Italy',
#  116: 'Montalcino, Tuscany, Italy',
#  117: 'Montalcino, Tuscany, Italy',
#  118: 'Montalcino, Tuscany, Italy',
#  119: 'Montalcino, Tuscany, Italy',
#  120: 'Montalcino, Tuscany, Italy',
#  121: 'Montalcino, Tuscany, Italy',
#  122: 'Montalcino, Tuscany, Italy',
#  123: 'Montalcino, Tuscany, Italy',
#  124: 'Montalcino, Tuscany, Italy',
#  125: 'Montalcino, Tuscany, Italy',
#  126: 'Montalcino, Tuscany, Italy',
#  127: 'Montalcino, Tuscany, Italy',
#  128: 'France',
#  129: 'France',
#  130: 'France',
#  131: 'Cahors, Southwest, France',
#  132: 'Prosecco, Italy',
#  133: 'Valdobbiadene, Prosecco, Italy',
#  134: 'Valdobbiadene, Prosecco, Italy',
#  135: 'Chianti Classico, Chianti, Tuscany, Italy',
#  136: 'Chianti Classico, Chianti, Tuscany, Italy',
#  137: 'Chianti Classico, Chianti, Tuscany, Italy',
#  138: 'Chianti Classico, Chianti, Tuscany, Italy',
#  139: 'Chianti Classico, Chianti, Tuscany, Italy',
#  140: 'Chianti Classico, Chianti, Tuscany, Italy',
#  141: 'Chianti Classico, Chianti, Tuscany, Italy',
#  142: 'Chianti Classico, Chianti, Tuscany, Italy',
#  143: 'Chianti Classico, Chianti, Tuscany, Italy',
#  144: 'Tuscany, Italy',
#  145: 'Chablis, Burgundy, France',
#  146: 'Chablis, Burgundy, France',
#  147: 'Chablis, Burgundy, France',
#  148: 'St. Emilion, Bordeaux, France',
#  149: 'St. Emilion, Bordeaux, France',
#  150: 'St. Emilion, Bordeaux, France',
#  151: 'St. Emilion, Bordeaux, France',
#  152: 'St. Emilion, Bordeaux, France',
#  153: 'Friuli-Venezia Giulia, Italy',
#  154: 'Friuli-Venezia Giulia, Italy',
#  155: 'St. Emilion, Bordeaux, France',
#  156: 'St. Emilion, Bordeaux, France',
#  157: 'St. Emilion, Bordeaux, France',
#  158: 'Chianti Classico, Chianti, Tuscany, Italy',
#  159: 'France',
#  160: 'France',
#  161: 'Chateauneuf-du-Pape, Rhone, France',
#  162: 'Bolgheri, Tuscany, Italy',
#  163: 'Bolgheri, Tuscany, Italy',
#  164: 'Bolgheri, Tuscany, Italy',
#  165: 'Bolgheri, Tuscany, Italy',
#  166: 'Bolgheri, Tuscany, Italy',
#  167: 'Bolgheri, Tuscany, Italy',
#  168: 'Bolgheri, Tuscany, Italy',
#  169: 'Bolgheri, Tuscany, Italy',
#  170: 'Bolgheri, Tuscany, Italy',
#  171: 'Tuscany, Italy',
#  172: 'Bolgheri, Tuscany, Italy',
#  173: 'Tuscany, Italy',
#  174: 'Tuscany, Italy',
#  175: 'Tuscany, Italy',
#  176: 'Tuscany, Italy',
#  177: 'Tuscany, Italy',
#  178: 'Tuscany, Italy',
#  179: 'Tuscany, Italy',
#  180: 'Tuscany, Italy',
#  181: 'Tuscany, Italy',
#  182: 'Tuscany, Italy',
#  183: 'Tuscany, Italy',
#  184: 'Tuscany, Italy',
#  185: 'Tuscany, Italy',
#  186: 'Tuscany, Italy',
#  187: 'Tuscany, Italy',
#  188: 'Tuscany, Italy',
#  189: 'Tuscany, Italy',
#  190: 'Tuscany, Italy',
#  191: 'Tuscany, Italy',
#  192: 'Tuscany, Italy',
#  193: 'Tuscany, Italy',
#  194: 'Tuscany, Italy',
#  195: 'Tuscany, Italy',
#  196: 'Tuscany, Italy',
#  197: 'Tuscany, Italy',
#  198: 'Tuscany, Italy',
#  199: 'Tuscany, Italy',
#  200: 'Tuscany, Italy',
#  201: 'Tuscany, Italy',
#  202: 'Tuscany, Italy',
#  203: 'Tuscany, Italy',
#  204: 'Tuscany, Italy',
#  205: 'Tuscany, Italy',
#  206: 'Tuscany, Italy',
#  207: 'Tuscany, Italy',
#  208: 'Tuscany, Italy',
#  209: 'Tuscany, Italy',
#  210: 'Tuscany, Italy',
#  211: 'Tuscany, Italy',
#  212: 'Tuscany, Italy',
#  213: 'Tuscany, Italy',
#  214: 'Central Coast, California',
#  215: 'Rhone, France',
#  216: 'Tuscany, Italy',
#  217: 'Montalcino, Tuscany, Italy',
#  218: 'Montalcino, Tuscany, Italy',
#  219: 'Montalcino, Tuscany, Italy',
#  220: 'Montalcino, Tuscany, Italy',
#  221: 'Montalcino, Tuscany, Italy',
#  222: 'Montalcino, Tuscany, Italy',
#  223: 'Montalcino, Tuscany, Italy',
#  224: 'Montalcino, Tuscany, Italy',
#  225: 'Montalcino, Tuscany, Italy',
#  226: 'Montalcino, Tuscany, Italy',
#  227: 'Montalcino, Tuscany, Italy',
#  228: 'Monterey, Central Coast, California',
#  229: 'Central Coast, California',
#  230: 'Monterey, Central Coast, California',
#  231: 'Central Coast, California',
#  232: 'Central Coast, California',
#  233: 'Central Coast, California',
#  234: 'San Benito, Central Coast, California',
#  235: 'San Benito, Central Coast, California',
#  236: 'Central Coast, California',
#  237: 'San Benito, Central Coast, California',
#  238: 'San Benito, Central Coast, California',
#  239: 'Central Coast, California',
#  240: 'Central Coast, California',
#  241: 'Monterey, Central Coast, California',
#  242: 'Monterey, Central Coast, California',
#  243: 'Central Coast, California',
#  244: 'Montalcino, Tuscany, Italy',
#  245: 'Valpolicella, Veneto, Italy',
#  246: 'Valpolicella, Veneto, Italy',
#  247: 'Sancerre, Loire, France',
#  248: 'Sancerre, Loire, France',
#  249: 'Sancerre, Loire, France',
#  250: 'Sancerre, Loire, France',
#  251: 'Veneto, Italy',
#  252: 'Veneto, Italy',
#  253: 'Veneto, Italy',
#  254: 'Valpolicella, Veneto, Italy',
#  255: 'Veneto, Italy',
#  256: 'Veneto, Italy',
#  257: 'Veneto, Italy',
#  258: 'Veneto, Italy',
#  259: 'Veneto, Italy',
#  260: 'Veneto, Italy',
#  261: 'Veneto, Italy',
#  262: 'Valpolicella, Veneto, Italy',
#  263: 'Marche, Italy',
#  264: 'Chateauneuf-du-Pape, Rhone, France',
#  265: 'Chateauneuf-du-Pape, Rhone, France',
#  266: 'Chateauneuf-du-Pape, Rhone, France',
#  267: 'Chateauneuf-du-Pape, Rhone, France',
#  268: 'Chateauneuf-du-Pape, Rhone, France',
#  269: 'Chateauneuf-du-Pape, Rhone, France',
#  270: 'Chateauneuf-du-Pape, Rhone, France',
#  271: 'Chateauneuf-du-Pape, Rhone, France',
#  272: 'Chateauneuf-du-Pape, Rhone, France',
#  273: 'Chateauneuf-du-Pape, Rhone, France',
#  274: 'Chateauneuf-du-Pape, Rhone, France',
#  275: 'Chateauneuf-du-Pape, Rhone, France',
#  276: 'Chateauneuf-du-Pape, Rhone, France',
#  277: 'Chateauneuf-du-Pape, Rhone, France',
#  278: 'Sicily, Italy',
#  279: 'Italy',
#  280: 'Sicily, Italy',
#  281: 'Sicily, Italy',
#  282: 'Paso Robles, Central Coast, California',
#  283: 'Sta. Rita Hills, Santa Barbara, Central Coast, California',
#  284: 'Sta. Rita Hills, Santa Barbara, Central Coast, California',
#  285: 'Portugal',
#  286: 'Portugal',
#  287: 'Madeira, Portugal',
#  288: 'Napa Valley, California',
#  289: 'Australia',
#  290: 'Australia',
#  291: 'Australia',
#  292: 'Australia',
#  293: 'Australia',
#  294: 'Australia',
#  295: 'Clare Valley, South Australia, Australia',
#  296: 'Clare Valley, South Australia, Australia',
#  297: 'Clare Valley, South Australia, Australia',
#  298: 'Clare Valley, South Australia, Australia',
#  299: 'Clare Valley, South Australia, Australia',
#  300: 'Australia',
#  301: 'Australia',
#  302: 'Australia',
#  303: 'Clare Valley, South Australia, Australia',
#  304: 'Clare Valley, South Australia, Australia',
#  305: 'Clare Valley, South Australia, Australia',
#  306: 'Clare Valley, South Australia, Australia',
#  307: 'Clare Valley, South Australia, Australia',
#  308: "Gevrey-Chambertin, Cote de Nuits, Cote d'Or, Burgundy, France",
#  309: "Gevrey-Chambertin, Cote de Nuits, Cote d'Or, Burgundy, France",
#  310: "Morey-St-Denis, Cote de Nuits, Cote d'Or, Burgundy, France",
#  311: "Morey-St-Denis, Cote de Nuits, Cote d'Or, Burgundy, France",
#  312: "Morey-St-Denis, Cote de Nuits, Cote d'Or, Burgundy, France",
#  313: "Morey-St-Denis, Cote de Nuits, Cote d'Or, Burgundy, France",
#  314: "Nuits-St-Georges, Cote de Nuits, Cote d'Or, Burgundy, France",
#  315: "Nuits-St-Georges, Cote de Nuits, Cote d'Or, Burgundy, France",
#  316: 'Burgundy, France',
#  317: 'Burgundy, France',
#  318: "Nuits-St-Georges, Cote de Nuits, Cote d'Or, Burgundy, France",
#  319: 'Burgundy, France',
#  320: "Nuits-St-Georges, Cote de Nuits, Cote d'Or, Burgundy, France",
#  321: 'Columbia Valley, Washington',
#  322: 'Columbia Valley, Washington',
#  323: 'Columbia Valley, Washington',
#  324: 'Columbia Valley, Washington',
#  325: 'Columbia Valley, Washington',
#  326: 'Columbia Valley, Washington',
#  327: 'Columbia Valley, Washington',
#  328: 'Columbia Valley, Washington',
#  329: 'Columbia Valley, Washington',
#  330: 'Columbia Valley, Washington',
#  331: 'Columbia Valley, Washington',
#  332: 'Columbia Valley, Washington',
#  333: 'Columbia Valley, Washington',
#  334: 'Columbia Valley, Washington',
#  335: 'Columbia Valley, Washington',
#  336: 'Columbia Valley, Washington',
#  337: 'Columbia Valley, Washington',
#  338: 'Columbia Valley, Washington',
#  339: 'Columbia Valley, Washington',
#  340: 'Columbia Valley, Washington',
#  341: 'Columbia Valley, Washington',
#  342: 'Columbia Valley, Washington',
#  343: 'Columbia Valley, Washington',
#  344: 'Columbia Valley, Washington',
#  345: 'Columbia Valley, Washington',
#  346: 'Columbia Valley, Washington',
#  347: 'Columbia Valley, Washington',
#  348: 'Columbia Valley, Washington',
#  349: 'Columbia Valley, Washington',
#  350: 'Columbia Valley, Washington',
#  351: 'Columbia Valley, Washington',
#  352: 'Columbia Valley, Washington',
#  353: 'Columbia Valley, Washington',
#  354: 'Columbia Valley, Washington',
#  355: 'Columbia Valley, Washington',
#  356: 'Columbia Valley, Washington',
#  357: 'Walla Walla Valley, Columbia Valley, Washington',
#  358: 'Walla Walla Valley, Columbia Valley, Washington',
#  359: 'Walla Walla Valley, Columbia Valley, Washington',
#  360: 'Walla Walla Valley, Columbia Valley, Washington',
#  361: 'Columbia Valley, Washington',
#  362: 'Columbia Valley, Washington',
#  363: 'Walla Walla Valley, Columbia Valley, Washington',
#  364: 'Walla Walla Valley, Columbia Valley, Washington',
#  365: 'Walla Walla Valley, Columbia Valley, Washington',
#  366: 'Walla Walla Valley, Columbia Valley, Washington',
#  367: 'Walla Walla Valley, Columbia Valley, Washington',
#  368: 'Walla Walla Valley, Columbia Valley, Washington',
#  369: 'Walla Walla Valley, Columbia Valley, Washington',
#  370: 'Walla Walla Valley, Columbia Valley, Washington',
#  371: 'Walla Walla Valley, Columbia Valley, Washington',
#  372: 'Columbia Valley, Washington',
#  373: 'Washington',
#  374: 'Columbia Valley, Washington',
#  375: 'Columbia Valley, Washington',
#  376: 'Columbia Valley, Washington',
#  377: 'Columbia Valley, Washington',
#  378: 'Columbia Valley, Washington',
#  379: 'Walla Walla Valley, Columbia Valley, Washington',
#  380: 'Walla Walla Valley, Columbia Valley, Washington',
#  381: 'Walla Walla Valley, Columbia Valley, Washington',
#  382: 'Walla Walla Valley, Columbia Valley, Washington',
#  383: 'Walla Walla Valley, Columbia Valley, Washington',
#  384: 'Walla Walla Valley, Columbia Valley, Washington',
#  385: 'Walla Walla Valley, Columbia Valley, Washington',
#  386: 'Columbia Valley, Washington',
#  387: 'Columbia Valley, Washington',
#  388: 'Columbia Valley, Washington',
#  389: 'Columbia Valley, Washington',
#  390: 'Columbia Valley, Washington',
#  391: 'Columbia Valley, Washington',
#  392: 'Columbia Valley, Washington',
#  393: 'Columbia Valley, Washington',
#  394: 'Columbia Valley, Washington',
#  395: 'Columbia Valley, Washington',
#  396: 'Walla Walla Valley, Columbia Valley, Washington',
#  397: 'Walla Walla Valley, Columbia Valley, Washington',
#  398: 'Walla Walla Valley, Columbia Valley, Washington',
#  399: 'Walla Walla Valley, Columbia Valley, Washington',
#  400: 'Walla Walla Valley, Columbia Valley, Washington',
#  401: 'Walla Walla Valley, Columbia Valley, Washington',
#  402: 'Walla Walla Valley, Columbia Valley, Washington',
#  403: 'Walla Walla Valley, Columbia Valley, Washington',
#  404: 'Walla Walla Valley, Columbia Valley, Washington',
#  405: 'Walla Walla Valley, Columbia Valley, Washington',
#  406: 'Walla Walla Valley, Columbia Valley, Washington',
#  407: 'Walla Walla Valley, Columbia Valley, Washington',
#  408: 'Walla Walla Valley, Columbia Valley, Washington',
#  409: 'Walla Walla Valley, Columbia Valley, Washington',
#  410: 'Walla Walla Valley, Columbia Valley, Washington',
#  411: 'Walla Walla Valley, Columbia Valley, Washington',
#  412: 'Walla Walla Valley, Columbia Valley, Washington',
#  413: 'Washington',
#  414: 'Walla Walla Valley, Columbia Valley, Washington',
#  415: 'Walla Walla Valley, Columbia Valley, Washington',
#  416: 'Walla Walla Valley, Columbia Valley, Washington',
#  417: 'Walla Walla Valley, Columbia Valley, Washington',
#  418: 'Walla Walla Valley, Columbia Valley, Washington',
#  419: 'Walla Walla Valley, Columbia Valley, Washington',
#  420: 'Walla Walla Valley, Columbia Valley, Washington',
#  421: 'Walla Walla Valley, Columbia Valley, Washington',
#  422: 'Walla Walla Valley, Columbia Valley, Washington',
#  423: 'Walla Walla Valley, Columbia Valley, Washington',
#  424: 'Walla Walla Valley, Columbia Valley, Washington',
#  425: 'Walla Walla Valley, Columbia Valley, Washington',
#  426: 'Walla Walla Valley, Columbia Valley, Washington',
#  427: 'California',
#  428: 'Paso Robles, Central Coast, California',
#  429: 'California',
#  430: 'California',
#  431: 'California',
#  432: 'California',
#  433: 'California',
#  434: 'California',
#  435: 'California',
#  436: 'California',
#  437: 'California',
#  438: 'California',
#  439: 'Margaret River, Western Australia, Australia',
#  440: 'Margaret River, Western Australia, Australia',
#  441: 'Margaret River, Western Australia, Australia',
#  442: 'Margaret River, Western Australia, Australia',
#  443: 'Margaret River, Western Australia, Australia',
#  444: 'Margaret River, Western Australia, Australia',
#  445: 'Margaret River, Western Australia, Australia',
#  446: 'Margaret River, Western Australia, Australia',
#  447: 'Margaret River, Western Australia, Australia',
#  448: 'Margaret River, Western Australia, Australia',
#  449: 'Margaret River, Western Australia, Australia',
#  450: 'Margaret River, Western Australia, Australia',
#  451: 'Margaret River, Western Australia, Australia',
#  452: 'Margaret River, Western Australia, Australia',
#  453: 'Margaret River, Western Australia, Australia',
#  454: 'Margaret River, Western Australia, Australia',
#  455: 'Margaret River, Western Australia, Australia',
#  456: 'Margaret River, Western Australia, Australia',
#  457: 'Margaret River, Western Australia, Australia',
#  458: 'Margaret River, Western Australia, Australia',
#  459: 'Margaret River, Western Australia, Australia',
#  460: 'Margaret River, Western Australia, Australia',
#  461: 'Margaret River, Western Australia, Australia',
#  462: 'Margaret River, Western Australia, Australia',
#  463: 'Margaret River, Western Australia, Australia',
#  464: 'Margaret River, Western Australia, Australia',
#  465: 'Margaret River, Western Australia, Australia',
#  466: 'Margaret River, Western Australia, Australia',
#  467: 'Margaret River, Western Australia, Australia',
#  468: 'Margaret River, Western Australia, Australia',
#  469: 'Margaret River, Western Australia, Australia',
#  470: 'Margaret River, Western Australia, Australia',
#  471: 'Margaret River, Western Australia, Australia',
#  472: 'Margaret River, Western Australia, Australia',
#  473: 'Margaret River, Western Australia, Australia',
#  474: 'Margaret River, Western Australia, Australia',
#  475: 'Margaret River, Western Australia, Australia',
#  476: 'Margaret River, Western Australia, Australia',
#  477: 'Margaret River, Western Australia, Australia',
#  478: 'Margaret River, Western Australia, Australia',
#  479: 'Margaret River, Western Australia, Australia',
#  480: 'Margaret River, Western Australia, Australia',
#  481: 'Margaret River, Western Australia, Australia',
#  482: 'Margaret River, Western Australia, Australia',
#  483: 'Margaret River, Western Australia, Australia',
#  484: 'Margaret River, Western Australia, Australia',
#  485: 'Margaret River, Western Australia, Australia',
#  486: 'Margaret River, Western Australia, Australia',
#  487: 'Margaret River, Western Australia, Australia',
#  488: 'Margaret River, Western Australia, Australia',
#  489: 'Margaret River, Western Australia, Australia',
#  490: 'Margaret River, Western Australia, Australia',
#  491: 'Margaret River, Western Australia, Australia',
#  492: 'Margaret River, Western Australia, Australia',
#  493: 'Margaret River, Western Australia, Australia',
#  494: 'Margaret River, Western Australia, Australia',
#  495: 'Margaret River, Western Australia, Australia',
#  496: 'Margaret River, Western Australia, Australia',
#  497: 'Margaret River, Western Australia, Australia',
#  498: 'Margaret River, Western Australia, Australia',
#  499: 'Margaret River, Western Australia, Australia',
#  500: 'Margaret River, Western Australia, Australia',
#  501: 'Margaret River, Western Australia, Australia',
#  502: 'Margaret River, Western Australia, Australia',
#  503: 'Margaret River, Western Australia, Australia',
#  504: 'Margaret River, Western Australia, Australia',
#  505: 'Margaret River, Western Australia, Australia',
#  506: 'Margaret River, Western Australia, Australia',
#  507: 'Margaret River, Western Australia, Australia',
#  508: 'Margaret River, Western Australia, Australia',
#  509: 'Margaret River, Western Australia, Australia',
#  510: 'Margaret River, Western Australia, Australia',
#  511: 'Margaret River, Western Australia, Australia',
#  512: 'Margaret River, Western Australia, Australia',
#  513: 'Margaret River, Western Australia, Australia',
#  514: 'Margaret River, Western Australia, Australia',
#  515: 'Margaret River, Western Australia, Australia',
#  516: 'Margaret River, Western Australia, Australia',
#  517: 'Margaret River, Western Australia, Australia',
#  518: 'Margaret River, Western Australia, Australia',
#  519: 'Margaret River, Western Australia, Australia',
#  520: 'Margaret River, Western Australia, Australia',
#  521: 'Margaret River, Western Australia, Australia',
#  522: 'Margaret River, Western Australia, Australia',
#  523: 'Margaret River, Western Australia, Australia',
#  524: 'Margaret River, Western Australia, Australia',
#  525: 'Margaret River, Western Australia, Australia',
#  526: 'Margaret River, Western Australia, Australia',
#  527: 'Willamette Valley, Oregon',
#  528: 'Willamette Valley, Oregon',
#  529: 'Willamette Valley, Oregon',
#  530: 'Willamette Valley, Oregon',
#  531: 'Willamette Valley, Oregon',
#  532: 'Willamette Valley, Oregon',
#  533: 'Alexander Valley, Sonoma County, California',
#  534: 'Ribera del Duero, Spain',
#  535: 'Ribera del Duero, Spain',
#  536: 'Ribera del Duero, Spain',
#  537: 'Ribera del Duero, Spain',
#  538: 'Oregon',
#  539: 'Willamette Valley, Oregon',
#  540: 'Willamette Valley, Oregon',
#  541: 'Willamette Valley, Oregon',
#  542: 'Willamette Valley, Oregon',
#  543: 'Dundee Hills, Willamette Valley, Oregon',
#  544: 'Dundee Hills, Willamette Valley, Oregon',
#  545: 'Dundee Hills, Willamette Valley, Oregon',
#  546: 'Yamhill-Carlton District, Willamette Valley, Oregon',
#  547: 'Oregon',
#  548: 'Willamette Valley, Oregon',
#  549: 'Oregon',
#  550: 'Willamette Valley, Oregon',
#  551: 'Willamette Valley, Oregon',
#  552: 'McLaren Vale, South Australia, Australia',
#  553: 'McLaren Vale, South Australia, Australia',
#  554: 'Australia',
#  555: 'Santa Cruz Mountains, California',
#  556: 'Santa Ynez Valley, Santa Barbara, Central Coast, California',
#  557: 'Santa Ynez Valley, Santa Barbara, Central Coast, California',
#  558: 'Santa Cruz Mountains, California',
#  559: 'Santa Ynez Valley, Santa Barbara, Central Coast, California',
#  560: 'Santa Ynez Valley, Santa Barbara, Central Coast, California',
#  561: 'Mendocino, California',
#  562: 'Dry Creek Valley, Sonoma County, California',
#  563: 'Dry Creek Valley, Sonoma County, California',
#  564: 'Dry Creek Valley, Sonoma County, California',
#  565: 'Dry Creek Valley, Sonoma County, California',
#  566: 'Sonoma Mountain, Sonoma Valley, Sonoma County, California',
#  567: 'Italy',
#  568: 'Italy',
#  569: 'Italy',
#  570: 'Puglia, Italy',
#  571: 'Puglia, Italy',
#  572: 'Italy',
#  573: 'Italy',
#  574: 'Walla Walla Valley, Columbia Valley, Washington',
#  575: 'Italy',
#  576: 'Columbia Valley, Washington',
#  577: 'Columbia Valley, Washington',
#  578: 'Columbia Valley, Washington',
#  579: 'Walla Walla Valley, Columbia Valley, Washington',
#  580: 'Walla Walla Valley, Columbia Valley, Washington',
#  581: 'Walla Walla Valley, Columbia Valley, Washington',
#  582: 'Walla Walla Valley, Columbia Valley, Washington',
#  583: 'Walla Walla Valley, Columbia Valley, Washington',
#  584: 'Walla Walla Valley, Columbia Valley, Washington',
#  585: 'Walla Walla Valley, Columbia Valley, Washington',
#  586: 'Walla Walla Valley, Columbia Valley, Washington',
#  587: 'Walla Walla Valley, Columbia Valley, Washington',
#  588: 'Walla Walla Valley, Columbia Valley, Washington',
#  589: 'Walla Walla Valley, Columbia Valley, Washington',
#  590: 'Walla Walla Valley, Columbia Valley, Washington',
#  591: 'Washington',
#  592: 'Columbia Valley, Washington',
#  593: 'Columbia Valley, Washington',
#  594: 'Columbia Valley, Washington',
#  595: 'Columbia Valley, Washington',
#  596: 'Columbia Valley, Washington',
#  597: 'Walla Walla Valley, Columbia Valley, Washington',
#  598: 'Walla Walla Valley, Columbia Valley, Washington',
#  599: 'Walla Walla Valley, Columbia Valley, Washington',
#  600: 'Walla Walla Valley, Columbia Valley, Washington',
#  601: 'Walla Walla Valley, Columbia Valley, Washington',
#  602: 'Walla Walla Valley, Columbia Valley, Washington',
#  603: 'Walla Walla Valley, Columbia Valley, Washington',
#  604: 'Walla Walla Valley, Columbia Valley, Washington',
#  605: 'Walla Walla Valley, Columbia Valley, Washington',
#  606: 'Walla Walla Valley, Columbia Valley, Washington',
#  607: 'Walla Walla Valley, Columbia Valley, Washington',
#  608: 'Walla Walla Valley, Columbia Valley, Washington',
#  609: 'Columbia Valley, Washington',
#  610: 'Walla Walla Valley, Columbia Valley, Washington',
#  611: 'Walla Walla Valley, Columbia Valley, Washington',
#  612: 'Walla Walla Valley, Columbia Valley, Washington',
#  613: 'Walla Walla Valley, Columbia Valley, Washington',
#  614: 'Walla Walla Valley, Columbia Valley, Washington',
#  615: 'Walla Walla Valley, Columbia Valley, Washington',
#  616: 'Walla Walla Valley, Columbia Valley, Washington',
#  617: 'Walla Walla Valley, Columbia Valley, Washington',
#  618: 'Walla Walla Valley, Columbia Valley, Washington',
#  619: 'Walla Walla Valley, Columbia Valley, Washington',
#  620: 'Walla Walla Valley, Columbia Valley, Washington',
#  621: 'Walla Walla Valley, Columbia Valley, Washington',
#  622: 'Walla Walla Valley, Columbia Valley, Washington',
#  623: 'Walla Walla Valley, Columbia Valley, Washington',
#  624: 'Walla Walla Valley, Columbia Valley, Washington',
#  625: 'Walla Walla Valley, Columbia Valley, Washington',
#  626: 'Walla Walla Valley, Columbia Valley, Washington',
#  627: 'Walla Walla Valley, Columbia Valley, Washington',
#  628: 'Walla Walla Valley, Columbia Valley, Washington',
#  629: 'Walla Walla Valley, Columbia Valley, Washington',
#  630: 'Walla Walla Valley, Columbia Valley, Washington',
#  631: 'Walla Walla Valley, Columbia Valley, Washington',
#  632: 'Walla Walla Valley, Columbia Valley, Washington',
#  633: 'Walla Walla Valley, Columbia Valley, Washington',
#  634: 'Columbia Valley, Washington',
#  635: 'Cornas, Rhone, France',
#  636: 'Crozes-Hermitage, Rhone, France',
#  637: 'Saint-Joseph, Rhone, France',
#  638: 'Saint-Joseph, Rhone, France',
#  639: 'Crozes-Hermitage, Rhone, France',
#  640: 'Vin de France, France',
#  641: 'Cotes du Rhone, Rhone, France',
#  642: 'Cotes du Rhone, Rhone, France',
#  643: 'St. Emilion, Bordeaux, France',
#  644: 'St. Emilion, Bordeaux, France',
#  645: 'St. Emilion, Bordeaux, France',
#  646: 'St. Emilion, Bordeaux, France',
#  647: 'St. Emilion, Bordeaux, France',
#  648: 'St. Emilion, Bordeaux, France',
#  649: 'Chateauneuf-du-Pape, Rhone, France',
#  650: 'Chateauneuf-du-Pape, Rhone, France',
#  651: 'Chateauneuf-du-Pape, Rhone, France',
#  652: 'Italy',
#  653: "Valle d'Aosta, Italy",
#  654: "Valle d'Aosta, Italy",
#  655: 'Italy',
#  656: "Valle d'Aosta, Italy",
#  657: 'Pauillac, Bordeaux, France',
#  658: 'Pauillac, Bordeaux, France',
#  659: 'Pauillac, Bordeaux, France',
#  660: 'Pauillac, Bordeaux, France',
#  661: 'Pauillac, Bordeaux, France',
#  662: 'Pauillac, Bordeaux, France',
#  663: 'Pauillac, Bordeaux, France',
#  664: 'Cotes du Rhone, Rhone, France',
#  665: 'Chateauneuf-du-Pape, Rhone, France',
#  666: 'Chateauneuf-du-Pape, Rhone, France',
#  667: 'Cotes du Rhone, Rhone, France',
#  668: 'Bordeaux, France',
#  669: "Coteaux d'Aix-en-Provence, Provence, South of France, France",
#  670: 'Cotes du Rhone, Rhone, France',
#  671: 'Cotes du Rhone, Rhone, France',
#  672: 'Cotes du Roussillon-Tautavel, Côtes du Roussillon-Villages, Roussillon, South of France, France',
#  673: 'Cotes du Rhone, Rhone, France',
#  674: 'Provence, South of France, France',
#  675: 'Terrasses du Larzac, Languedoc, South of France, France',
#  676: 'Pessac-Leognan, Bordeaux, France',
#  677: 'Austria',
#  678: 'Austria',
#  679: 'Austria',
#  680: 'Austria',
#  681: 'Austria',
#  682: 'Austria',
#  683: 'Austria',
#  684: 'Russian River, Sonoma County, California',
#  685: 'Napa Valley, California',
#  686: 'Napa Valley, California',
#  687: 'Cote Rotie, Rhone, France',
#  688: 'Cote Rotie, Rhone, France',
#  689: 'California',
#  690: 'California',
#  691: 'North Coast, California',
#  692: 'Napa Valley, California',
#  693: 'Napa Valley, California',
#  694: 'Napa Valley, California',
#  695: 'St. Helena, Napa Valley, California',
#  696: 'St. Helena, Napa Valley, California',
#  697: 'St. Helena, Napa Valley, California',
#  698: 'St. Helena, Napa Valley, California',
#  699: 'St. Helena, Napa Valley, California',
#  700: 'St. Helena, Napa Valley, California',
#  701: 'St. Helena, Napa Valley, California',
#  702: 'Napa Valley, California',
#  703: 'Napa Valley, California',
#  704: 'St. Helena, Napa Valley, California',
#  705: 'St. Helena, Napa Valley, California',
#  706: 'Napa Valley, California',
#  707: 'St. Helena, Napa Valley, California',
#  708: 'St. Helena, Napa Valley, California',
#  709: 'Napa Valley, California',
#  710: 'Napa Valley, California',
#  711: 'Napa Valley, California',
#  712: 'Napa Valley, California',
#  713: 'Napa Valley, California',
#  714: 'Napa Valley, California',
#  715: 'Napa Valley, California',
#  716: 'Napa Valley, California',
#  717: 'Napa Valley, California',
#  718: 'Russian River, Sonoma County, California',
#  719: 'Russian River, Sonoma County, California',
#  720: 'Russian River, Sonoma County, California',
#  721: 'Russian River, Sonoma County, California',
#  722: 'Russian River, Sonoma County, California',
#  723: 'Russian River, Sonoma County, California',
#  724: 'Napa Valley, California',
#  725: 'Napa Valley, California',
#  726: 'Napa Valley, California',
#  727: 'Napa Valley, California',
#  728: 'Napa Valley, California',
#  729: 'Napa Valley, California',
#  730: 'Napa Valley, California',
#  731: 'Napa Valley, California',
#  732: 'Napa Valley, California',
#  733: 'Napa Valley, California',
#  734: 'Napa Valley, California',
#  735: 'Napa Valley, California',
#  736: 'Rutherford, Napa Valley, California',
#  737: 'Napa Valley, California',
#  738: 'Napa Valley, California',
#  739: 'Napa Valley, California',
#  740: 'Napa Valley, California',
#  741: 'Napa Valley, California',
#  742: 'Napa Valley, California',
#  743: 'Napa Valley, California',
#  744: 'Napa Valley, California',
#  745: 'Napa Valley, California',
#  746: 'Napa Valley, California',
#  747: 'Napa Valley, California',
#  748: 'Napa Valley, California',
#  749: 'Napa Valley, California',
#  750: 'Napa Valley, California',
#  751: 'Napa Valley, California',
#  752: 'Napa Valley, California',
#  753: 'Napa Valley, California',
#  754: 'Napa Valley, California',
#  755: 'Napa Valley, California',
#  756: 'Napa Valley, California',
#  757: 'Napa Valley, California',
#  758: 'Napa Valley, California',
#  759: 'Napa Valley, California',
#  760: 'Napa Valley, California',
#  761: 'Napa Valley, California',
#  762: 'Napa Valley, California',
#  763: 'Napa Valley, California',
#  764: 'Napa Valley, California',
#  765: 'Napa Valley, California',
#  766: 'Napa Valley, California',
#  767: 'Napa Valley, California',
#  768: 'Napa Valley, California',
#  769: 'Napa Valley, California',
#  770: 'Napa Valley, California',
#  771: 'Russian River, Sonoma County, California',
#  772: 'Russian River, Sonoma County, California',
#  773: 'Russian River, Sonoma County, California',
#  774: 'Sonoma County, California',
#  775: 'California',
#  776: 'California',
#  777: 'California',
#  778: 'Santa Cruz Mountains, California',
#  779: 'Santa Cruz Mountains, California'}
